# %% [markdown]
# lexical semantics

# %%
import re
from textblob import Word
import nltk # import nltk

# Download the 'FRAMENET' dataset using nltk.download()
nltk.download('FRAMENET')  # Download wordnet

with open('word.txt', 'r') as file:
    text = file.read()

# Use regex to split the text into words, ignoring punctuation and converting to lowercase
words = re.findall(r'\b\w+\b', text.lower())

# Process each word for synonyms and antonyms
for word_str in set(words):  # Use set to avoid duplicate words or to use unique
    word = Word(word_str)

    synonyms = word.synsets

    antonyms = []
    for synset in synonyms:
        for lemma in synset.lemmas():
            if lemma.antonyms():
                antonyms.append(lemma.antonyms()[0].name())

    # Output the results
    print(f"Word: '{word_str}'")
    print(f"  Synonyms: {[lemma.name() for synset in synonyms for lemma in synset.lemmas()]}")
    print(f"  Antonyms: {antonyms}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Word: 'upon'
#   Synonyms: []
#   Antonyms: []
# Word: 'managing'
#   Synonyms: ['pull_off', 'negociate', 'bring_off', 'carry_off', 'manage', 'manage', 'deal', 'care', 'handle', 'cope', 'get_by', 'make_out', 'make_do', 'contend', 'grapple', 'deal', 'manage', 'oversee', 'supervise', 'superintend', 'manage', 'wangle', 'finagle', 'manage', 'do', 'manage', 'wield', 'handle', 'manage']
#   Antonyms: ['fail']
# Word: 'derive'
#   Synonyms: ['deduce', 'infer', 'deduct', 'derive', 'derive', 'gain', 'derive', 'derive', 'educe', 'derive', 'come', 'descend']
#   Antonyms: []
# Word: 'language'
#   Synonyms: ['language', 'linguistic_communication', 'speech', 'speech_communication', 'spoken_communication', 'spoken_language', 'language', 'voice_communication', 'oral_communication', 'lyric', 'words', 'language', 'linguistic_process', 'language', 'language', 'speech', 'terminology', 'nomenclature', 'language']
#   Antonyms: []
# Word: 'person'
#   Synonyms: ['person', 'individual', 'someone', 'somebody', 'mortal', 'soul', 'person', 'person']
#   Antonyms: []
# Word: 'applications'
#   Synonyms: ['application', 'practical_application', 'application', 'application', 'coating', 'covering', 'application', 'application_program', 'applications_programme', 'lotion', 'application', 'application', 'diligence', 'application']
#   Antonyms: []
# Word: 'indicative'
#   Synonyms: ['indicative_mood', 'indicative', 'declarative_mood', 'declarative', 'common_mood', 'fact_mood', 'indicative', 'declarative', 'indicative', 'indicatory', 'revelatory', 'significative', 'suggestive']
#   Antonyms: []
# Word: 'recognize'
#   Synonyms: ['acknowledge', 'recognize', 'recognise', 'know', 'recognize', 'recognise', 'realize', 'realise', 'agnize', 'agnise', 'spot', 'recognize', 'recognise', 'distinguish', 'discern', 'pick_out', 'make_out', 'tell_apart', 'recognize', 'recognise', 'accredit', 'recognize', 'recognise', 'greet', 'recognize', 'recognise', 'acknowledge', 'recognize', 'recognise', 'recognize', 'recognize', 'recognise']
#   Antonyms: []
# Word: 'cited'
#   Synonyms: ['mention', 'advert', 'bring_up', 'cite', 'name', 'refer', 'mention', 'cite', 'reference', 'cite', 'quote', 'cite', 'quote', 'cite', 'adduce', 'abduce', 'cite', 'summon', 'summons', 'cite']
#   Antonyms: []
# Word: 'permitting'
#   Synonyms: ['permit', 'allow', 'let', 'countenance', 'let', 'allow', 'permit', 'allow', 'permit', 'tolerate']
#   Antonyms: ['forbid', 'disallow', 'prevent']
# Word: 'devices'
#   Synonyms: ['devices', 'device', 'device', 'device', 'gimmick', 'twist', 'device', 'device']
#   Antonyms: []
# Word: 'nlp'
#   Synonyms: ['natural_language_processing', 'NLP', 'human_language_technology']
#   Antonyms: []
# Word: 'words'
#   Synonyms: ['words', 'lyric', 'words', 'language', 'words', 'quarrel', 'wrangle', 'row', 'words', 'run-in', 'dustup', "actor's_line", 'speech', 'words', 'word', 'word', 'news', 'intelligence', 'tidings', 'word', 'word', 'discussion', 'give-and-take', 'word', 'parole', 'word', 'word_of_honor', 'word', 'Son', 'Word', 'Logos', 'password', 'watchword', 'word', 'parole', 'countersign', 'Bible', 'Christian_Bible', 'Book', 'Good_Book', 'Holy_Scripture', 'Holy_Writ', 'Scripture', 'Word_of_God', 'Word', 'give_voice', 'formulate', 'word', 'phrase', 'articulate']
#   Antonyms: []
# Word: 'class'
#   Synonyms: ['class', 'category', 'family', 'class', 'form', 'grade', 'course', 'class', 'stratum', 'social_class', 'socio-economic_class', 'course', 'course_of_study', 'course_of_instruction', 'class', 'class', 'division', 'class', 'year', 'class', 'class', 'classify', 'class', 'sort', 'assort', 'sort_out', 'separate']
#   Antonyms: []
# Word: 'direct'
#   Synonyms: ['direct', 'target', 'aim', 'place', 'direct', 'point', 'direct', 'direct', 'lead', 'take', 'direct', 'conduct', 'guide', 'send', 'direct', 'aim', 'take', 'train', 'take_aim', 'direct', 'conduct', 'lead', 'direct', 'direct', 'calculate', 'aim', 'direct', 'steer', 'maneuver', 'manoeuver', 'manoeuvre', 'direct', 'point', 'head', 'guide', 'channelize', 'channelise', 'address', 'direct', 'mastermind', 'engineer', 'direct', 'organize', 'organise', 'orchestrate', 'direct', 'direct', 'unmediated', 'direct', 'lineal', 'direct', 'direct', 'direct', 'direct', 'direct', 'direct', 'verbatim', 'direct', 'directly', 'straight', 'direct']
#   Antonyms: ['indirect', 'indirect', 'collateral', 'retrograde', 'inverse', 'alternating']
# Word: 'purchaser'
#   Synonyms: ['buyer', 'purchaser', 'emptor', 'vendee']
#   Antonyms: []
# Word: 'monetary'
#   Synonyms: ['monetary', 'pecuniary']
#   Antonyms: []
# Word: 'detection'
#   Synonyms: ['detection', 'sensing', 'detection', 'catching', 'espial', 'spying', 'spotting', 'signal_detection', 'detection', 'detection', 'detecting', 'detective_work', 'sleuthing']
#   Antonyms: []
# Word: 'collection'
#   Synonyms: ['collection', 'aggregation', 'accumulation', 'assemblage', 'collection', 'compendium', 'solicitation', 'appeal', 'collection', 'ingathering', 'collection', 'collecting', 'assembling', 'aggregation']
#   Antonyms: []
# Word: 'from'
#   Synonyms: []
#   Antonyms: []
# Word: 'emails'
#   Synonyms: ['electronic_mail', 'e-mail', 'email', 'e-mail', 'email', 'netmail']
#   Antonyms: ['snail_mail', 'snail_mail', 'snail_mail']
# Word: 'branch'
#   Synonyms: ['branch', 'subdivision', 'arm', 'branch', 'branch', 'leg', 'ramification', 'outgrowth', 'branch', 'offshoot', 'offset', 'branch', 'arm', 'branch', 'limb', 'ramify', 'branch', 'branch', 'ramify', 'fork', 'furcate', 'separate']
#   Antonyms: []
# Word: 'phrases'
#   Synonyms: ['phrase', 'phrase', 'musical_phrase', 'idiom', 'idiomatic_expression', 'phrasal_idiom', 'set_phrase', 'phrase', 'phrase', 'give_voice', 'formulate', 'word', 'phrase', 'articulate', 'phrase']
#   Antonyms: []
# Word: 'textblob'
#   Synonyms: []
#   Antonyms: []
# Word: 'less'
#   Synonyms: ['lupus_erythematosus', 'LE', 'less', 'less', 'less', 'less', 'to_a_lesser_extent', 'less']
#   Antonyms: ['more', 'more', 'more']
# Word: 'response'
#   Synonyms: ['response', 'reaction', 'response', 'answer', 'reply', 'response', 'reception', 'response', 'response', 'reply', 'response', 'response']
#   Antonyms: []
# Word: 'is'
#   Synonyms: ['be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make_up', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
#   Antonyms: ['differ']
# Word: 'named'
#   Synonyms: ['name', 'call', 'name', 'identify', 'name', 'nominate', 'make', 'appoint', 'name', 'nominate', 'constitute', 'name', 'mention', 'advert', 'bring_up', 'cite', 'name', 'refer', 'identify', 'discover', 'key', 'key_out', 'distinguish', 'describe', 'name', 'list', 'name', 'diagnose', 'name']
#   Antonyms: []
# Word: 'insights'
#   Synonyms: ['penetration', 'insight', 'insight', 'perceptiveness', 'perceptivity', 'insight', 'brainstorm', 'brainwave', 'insight', 'sixth_sense']
#   Antonyms: []
# Word: 'elements'
#   Synonyms: ['elements', 'component', 'constituent', 'element', 'factor', 'ingredient', 'component', 'constituent', 'element', 'chemical_element', 'element', 'element', 'element', 'element', 'element']
#   Antonyms: []
# Word: 'posts'
#   Synonyms: ['post', 'station', 'military_post', 'post', 'position', 'post', 'berth', 'office', 'spot', 'billet', 'place', 'situation', 'post', 'Post', 'Wiley_Post', 'Post', 'Emily_Post', 'Emily_Price_Post', 'Post', 'C._W._Post', 'Charles_William_Post', 'mail', 'post', 'post', 'stake', 'mail', 'mail_service', 'postal_service', 'post', 'post', 'post', 'post', 'post', 'station', 'post', 'send', 'place', 'post', 'post', 'post', 'carry', 'post', 'stake', 'post', 'post', 'put_up', 'mail', 'post', 'send', 'post', 'brand']
#   Antonyms: []
# Word: 'conclusions'
#   Synonyms: ['decision', 'determination', 'conclusion', 'conclusion', 'stopping_point', 'finale', 'finis', 'finish', 'last', 'conclusion', 'close', 'ending', 'conclusion', 'finish', 'conclusion', 'ratiocination', 'termination', 'ending', 'conclusion', 'conclusion', 'conclusion', 'end', 'close', 'closing', 'ending', 'decision', 'determination', 'conclusion']
#   Antonyms: ['beginning']
# Word: 'difficult'
#   Synonyms: ['difficult', 'hard', 'unmanageable', 'difficult']
#   Antonyms: ['easy', 'manageable']
# Word: 'studying'
#   Synonyms: ['perusal', 'perusing', 'poring_over', 'studying', 'analyze', 'analyse', 'study', 'examine', 'canvass', 'canvas', 'study', 'study', 'consider', 'learn', 'study', 'read', 'take', 'study', 'hit_the_books', 'study', 'meditate', 'contemplate']
#   Antonyms: []
# Word: 'offerings'
#   Synonyms: ['offer', 'offering', 'offering', 'offer', 'offering', 'oblation', 'offering', 'offer', 'offer', 'proffer', 'volunteer', 'offer', 'offer', 'offer', 'extend', 'offer', 'offer', 'bid', 'tender', 'offer', 'offer', 'offer_up', 'put_up', 'provide', 'offer', 'extend', 'offer', 'propose', 'declare_oneself', 'offer', 'pop_the_question', 'offer']
#   Antonyms: []
# Word: 'domains'
#   Synonyms: ['sphere', 'domain', 'area', 'orbit', 'field', 'arena', 'domain', 'demesne', 'land', 'domain', 'domain_of_a_function', 'world', 'domain', 'knowledge_domain', 'knowledge_base', 'domain']
#   Antonyms: []
# Word: 'severa'
#   Synonyms: []
#   Antonyms: []
# Word: 'tone'
#   Synonyms: ['tone', 'tone_of_voice', 'tone', 'timbre', 'timber', 'quality', 'tone', 'spirit', 'tone', 'feel', 'feeling', 'flavor', 'flavour', 'look', 'smell', 'shade', 'tint', 'tincture', 'tone', 'note', 'musical_note', 'tone', 'tone', 'pure_tone', 'tonicity', 'tonus', 'tone', 'tone', 'whole_tone', 'step', 'whole_step', 'tone', 'tone', 'chant', 'intone', 'tone', 'inflect', 'modulate', 'tone', 'tone', 'tone', 'tone_up', 'strengthen']
#   Antonyms: ['atonicity']
# Word: 'observe'
#   Synonyms: ['detect', 'observe', 'find', 'discover', 'notice', 'note', 'observe', 'mention', 'remark', 'note', 'take_note', 'observe', 'observe', 'respect', 'honor', 'honour', 'abide_by', 'observe', 'observe', 'celebrate', 'keep', 'watch', 'observe', 'follow', 'watch_over', 'keep_an_eye_on', 'observe', 'keep', 'maintain', 'observe', 'keep']
#   Antonyms: ['disrespect', 'break']
# Word: 'assets'
#   Synonyms: ['assets', 'asset', 'plus']
#   Antonyms: ['liability']
# Word: 'including'
#   Synonyms: ['include', 'include', 'include', 'admit', 'let_in', 'include']
#   Antonyms: ['exclude', 'exclude', 'exclude']
# Word: 'meaningful'
#   Synonyms: ['meaningful']
#   Antonyms: ['meaningless']
# Word: 'the'
#   Synonyms: []
#   Antonyms: []
# Word: 'at'
#   Synonyms: ['astatine', 'At', 'atomic_number_85', 'at']
#   Antonyms: []
# Word: 'and'
#   Synonyms: []
#   Antonyms: []
# Word: 'equipment'
#   Synonyms: ['equipment']
#   Antonyms: []
# Word: 'datasets'
#   Synonyms: []
#   Antonyms: []
# Word: 'important'
#   Synonyms: ['important', 'of_import', 'significant', 'important', 'crucial', 'important', 'authoritative', 'important', 'important']
#   Antonyms: ['unimportant', 'insignificant', 'noncrucial']
# Word: 'comments'
#   Synonyms: ['remark', 'comment', 'input', 'comment', 'commentary', 'gossip', 'comment', 'scuttlebutt', 'comment', 'notice', 'remark', 'point_out', 'comment', 'gloss', 'comment', 'annotate']
#   Antonyms: []
# Word: 'strategies'
#   Synonyms: ['scheme', 'strategy', 'strategy']
#   Antonyms: []
# Word: 'interpret'
#   Synonyms: ['interpret', 'construe', 'see', 'rede', 'interpret', 'interpret', 'render', 'represent', 'interpret', 'translate', 'interpret', 'render', 'understand', 'read', 'interpret', 'translate']
#   Antonyms: []
# Word: 'select'
#   Synonyms: ['choose', 'take', 'select', 'pick_out', 'choice', 'prime', 'prize', 'quality', 'select', 'blue-ribbon', 'select']
#   Antonyms: []
# Word: 'duties'
#   Synonyms: ['duty', 'responsibility', 'obligation', 'duty', 'duty', 'tariff']
#   Antonyms: []
# Word: 'predefined'
#   Synonyms: []
#   Antonyms: []
# Word: 'which'
#   Synonyms: []
#   Antonyms: []
# Word: 'enhanced'
#   Synonyms: ['enhance', 'heighten', 'raise', 'enhance', 'enhanced']
#   Antonyms: []
# Word: 'case'
#   Synonyms: ['case', 'instance', 'example', 'event', 'case', 'lawsuit', 'suit', 'case', 'cause', 'causa', 'case', 'case', 'case', 'subject', 'case', 'guinea_pig', 'case', 'case', 'case', 'caseful', 'case', 'grammatical_case', 'case', 'character', 'eccentric', 'type', 'case', 'font', 'fount', 'typeface', 'face', 'case', 'sheath', 'case', 'shell', 'case', 'casing', 'casing', 'case', 'case', "compositor's_case", "typesetter's_case", 'case', 'pillowcase', 'slip', 'pillow_slip', 'case', 'display_case', 'showcase', 'vitrine', 'case', 'encase', 'incase', 'case']
#   Antonyms: []
# Word: 'research'
#   Synonyms: ['research', 'inquiry', 'enquiry', 'research', 'research', 'research', 'search', 'explore']
#   Antonyms: []
# Word: 'for'
#   Synonyms: []
#   Antonyms: []
# Word: 'simplify'
#   Synonyms: ['simplify']
#   Antonyms: ['complicate']
# Word: 'on'
#   Synonyms: ['on', 'on', 'along', 'on', 'on', 'on']
#   Antonyms: ['off', 'off']
# Word: 'prevention'
#   Synonyms: ['prevention', 'bar']
#   Antonyms: []
# Word: 'assessment'
#   Synonyms: ['appraisal', 'assessment', 'assessment', 'assessment', 'judgment', 'judgement', 'assessment']
#   Antonyms: []
# Word: 'had'
#   Synonyms: ['have', 'have_got', 'hold', 'have', 'feature', 'experience', 'receive', 'have', 'get', 'own', 'have', 'possess', 'get', 'let', 'have', 'consume', 'ingest', 'take_in', 'take', 'have', 'have', 'hold', 'throw', 'have', 'make', 'give', 'have', 'have', 'have', 'experience', 'have', 'induce', 'stimulate', 'cause', 'have', 'get', 'make', 'accept', 'take', 'have', 'receive', 'have', 'suffer', 'sustain', 'have', 'get', 'have', 'get', 'make', 'give_birth', 'deliver', 'bear', 'birth', 'have', 'take', 'have']
#   Antonyms: ['lack', 'abstain', 'refuse']
# Word: 'natural'
#   Synonyms: ['natural', 'natural', 'cancel', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'natural', 'instinctive', 'natural', 'raw', 'rude', 'natural', 'natural', 'born', 'innate', 'lifelike', 'natural']
#   Antonyms: ['unnatural', 'artificial', 'supernatural', 'sharp']
# Word: 'mining'
#   Synonyms: ['mining', 'excavation', 'mining', 'minelaying', 'mine', 'mine']
#   Antonyms: []
# Word: 'corpora'
#   Synonyms: ['principal', 'corpus', 'principal_sum', 'corpus', 'corpus']
#   Antonyms: []
# Word: 'elevated'
#   Synonyms: ['elevated_railway', 'elevated_railroad', 'elevated', 'el', 'overhead_railway', 'promote', 'upgrade', 'advance', 'kick_upstairs', 'raise', 'elevate', 'raise', 'lift', 'elevate', 'get_up', 'bring_up', 'lift', 'raise', 'elevate', 'elevated', 'exalted', 'elevated', 'sublime', 'grand', 'high-flown', 'high-minded', 'lofty', 'rarefied', 'rarified', 'idealistic', 'noble-minded', 'raised', 'elevated']
#   Antonyms: ['demote', 'lower']
# Word: 'huge'
#   Synonyms: ['huge', 'immense', 'vast', 'Brobdingnagian']
#   Antonyms: []
# Word: 'apprehend'
#   Synonyms: ['grok', 'get_the_picture', 'comprehend', 'savvy', 'dig', 'grasp', 'compass', 'apprehend', 'collar', 'nail', 'apprehend', 'arrest', 'pick_up', 'nab', 'cop', 'apprehend', 'quail_at']
#   Antonyms: []
# Word: 'cost'
#   Synonyms: ['cost', 'monetary_value', 'price', 'cost', 'price', 'cost', 'toll', 'cost', 'be', 'cost']
#   Antonyms: []
# Word: 'institutions'
#   Synonyms: ['institution', 'establishment', 'institution', 'institution', 'initiation', 'founding', 'foundation', 'institution', 'origination', 'creation', 'innovation', 'introduction', 'instauration', 'mental_hospital', 'psychiatric_hospital', 'mental_institution', 'institution', 'mental_home', 'insane_asylum', 'asylum']
#   Antonyms: []
# Word: 'this'
#   Synonyms: []
#   Antonyms: []
# Word: 'humans'
#   Synonyms: ['world', 'human_race', 'humanity', 'humankind', 'human_beings', 'humans', 'mankind', 'man', 'homo', 'man', 'human_being', 'human']
#   Antonyms: []
# Word: 'particular'
#   Synonyms: ['particular', 'specific', 'detail', 'particular', 'item', 'particular', 'particular_proposition', 'particular', 'peculiar', 'special', 'particular', 'especial', 'exceptional', 'particular', 'special', 'particular', 'special', 'finical', 'finicky', 'fussy', 'particular', 'picky', 'particular']
#   Antonyms: ['general', 'general', 'universal', 'universal_proposition']
# Word: 'regions'
#   Synonyms: ['region', 'part', 'area', 'region', 'region', 'region', 'neighborhood', 'region', 'realm']
#   Antonyms: []
# Word: 'criminal'
#   Synonyms: ['criminal', 'felon', 'crook', 'outlaw', 'malefactor', 'condemnable', 'criminal', 'deplorable', 'reprehensible', 'vicious', 'criminal', 'criminal', 'felonious']
#   Antonyms: []
# Word: 'part'
#   Synonyms: ['part', 'portion', 'component_part', 'component', 'constituent', 'part', 'portion', 'part', 'piece', 'part', 'region', 'part', 'function', 'office', 'part', 'role', 'character', 'role', 'theatrical_role', 'part', 'persona', 'share', 'portion', 'part', 'percentage', 'part', 'section', 'division', 'part', 'parting', 'part', 'voice', 'contribution', 'part', 'share', 'separate', 'part', 'split', 'separate', 'part', 'split_up', 'split', 'break', 'break_up', 'depart', 'part', 'start', 'start_out', 'set_forth', 'set_off', 'set_out', 'take_off', 'separate', 'divide', 'part', 'separate', 'disunite', 'divide', 'part', 'partially', 'partly', 'part']
#   Antonyms: ['wholly']
# Word: 'down'
#   Synonyms: ['down', 'down_feather', 'down', 'Down', 'John_L._H._Down', 'down', 'down', 'pile', 'toss_off', 'pop', 'bolt_down', 'belt_down', 'pour_down', 'down', 'drink_down', 'kill', 'devour', 'down', 'consume', 'go_through', 'down', 'down', 'shoot_down', 'land', 'down', 'knock_down', 'cut_down', 'push_down', 'pull_down', 'polish', 'refine', 'fine-tune', 'down', 'down', 'down', 'downward', 'down', 'down', 'down', 'down_pat', 'mastered', 'depressed', 'down', 'down', 'down', 'gloomy', 'grim', 'blue', 'depressed', 'dispirited', 'down', 'downcast', 'downhearted', 'down_in_the_mouth', 'low', 'low-spirited', 'down', 'downwards', 'downward', 'downwardly', 'down', 'down', 'down', 'down', 'down']
#   Antonyms: ['up', 'up', 'upwards', 'upward', 'upwardly', 'up', 'up']
# Word: 'textual'
#   Synonyms: ['textual']
#   Antonyms: []
# Word: 'way'
#   Synonyms: ['manner', 'mode', 'style', 'way', 'fashion', 'means', 'agency', 'way', 'direction', 'way', 'way', 'way', 'path', 'way_of_life', 'way', 'way', 'room', 'way', 'elbow_room', 'way', 'way', 'way', 'way', 'way', 'right_smart']
#   Antonyms: []
# Word: 'music'
#   Synonyms: ['music', 'music', 'euphony', 'music', 'music', 'music', 'medicine']
#   Antonyms: []
# Word: 'making'
#   Synonyms: ['devising', 'fashioning', 'making', 'qualification', 'making', 'making', 'make', 'do', 'make', 'get', 'make', 'create', 'induce', 'stimulate', 'cause', 'have', 'get', 'make', 'cause', 'do', 'make', 'produce', 'make', 'create', 'draw', 'make', 'make', 'create', 'make', 'gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in', 'do', 'make', 'form', 'constitute', 'make', 'reach', 'make', 'get_to', 'progress_to', 'make', 'make', 'make', 'construct', 'build', 'make', 'make', 'make', 'name', 'nominate', 'make', 'have', 'get', 'make', 'reach', 'make', 'attain', 'hit', 'arrive_at', 'gain', 'lay_down', 'establish', 'make', 'make', 'make', 'hold', 'throw', 'have', 'make', 'give', 'make', 'make_up', 'take', 'make', 'stool', 'defecate', 'shit', 'take_a_shit', 'take_a_crap', 'ca-ca', 'crap', 'make', 'make', 'make', 'make', 'make', 'make', 'make', 'make', 'work', 'make', 'make', 'cook', 'fix', 'ready', 'make', 'prepare', 'seduce', 'score', 'make', 'make', 'make', 'pretend', 'make_believe', 'make', 'make', 'make', 'make', 'make', 'make', 'make', 'urinate', 'piddle', 'puddle', 'micturate', 'piss', 'pee', 'pee-pee', 'make_water', 'relieve_oneself', 'take_a_leak', 'spend_a_penny', 'wee', 'wee-wee', 'pass_water']
#   Antonyms: ['unmake', 'break']
# Word: 'social'
#   Synonyms: ['sociable', 'social', 'mixer', 'social', 'societal', 'social', 'social', 'social', 'social', 'social']
#   Antonyms: ['unsocial']
# Word: 'inside'
#   Synonyms: ['inside', 'interior', 'inside', 'interior', 'inside', 'inside', 'inside', 'inner', 'privileged', 'inside', 'inside', 'indoors', 'inside', 'within', 'inwardly', 'inside', 'at_heart', 'at_bottom', 'deep_down', 'inside', 'in_spite_of_appearance']
#   Antonyms: ['outside', 'outside', 'outside', 'outside', 'outdoors', 'outside', 'outwardly']
# Word: 'support'
#   Synonyms: ['support', 'support', 'support', 'support', 'reinforcement', 'reenforcement', 'documentation', 'support', 'support', 'keep', 'livelihood', 'living', 'bread_and_butter', 'sustenance', 'support', 'support', 'supporting', 'accompaniment', 'musical_accompaniment', 'backup', 'support', 'support', 'support', 'financial_support', 'funding', 'backing', 'financial_backing', 'support', 'back_up', 'support', 'back', 'endorse', 'indorse', 'plump_for', 'plunk_for', 'support', 'hold', 'support', 'sustain', 'hold_up', 'confirm', 'corroborate', 'sustain', 'substantiate', 'support', 'affirm', 'subscribe', 'support', 'corroborate', 'underpin', 'bear_out', 'support', 'defend', 'support', 'fend_for', 'support', 'patronize', 'patronise', 'patronage', 'support', 'keep_going', 'digest', 'endure', 'stick_out', 'stomach', 'bear', 'stand', 'tolerate', 'support', 'brook', 'abide', 'suffer', 'put_up']
#   Antonyms: ['negate']
# Word: 'mentions'
#   Synonyms: ['mention', 'reference', 'citation', 'cite', 'acknowledgment', 'credit', 'reference', 'mention', 'quotation', 'mention', 'honorable_mention', 'mention', 'advert', 'bring_up', 'cite', 'name', 'refer', 'note', 'observe', 'mention', 'remark', 'mention', 'cite']
#   Antonyms: []
# Word: 'hassle'
#   Synonyms: ['fuss', 'trouble', 'bother', 'hassle', 'hassle', 'scuffle', 'tussle', 'dogfight', 'rough-and-tumble', 'harass', 'hassle', 'harry', 'chivy', 'chivvy', 'chevy', 'chevvy', 'beset', 'plague', 'molest', 'provoke']
#   Antonyms: []
# Word: 'hints'
#   Synonyms: ['hint', 'intimation', 'breath', 'hint', 'clue', 'touch', 'hint', 'tinge', 'mite', 'pinch', 'jot', 'speck', 'soupcon', 'trace', 'hint', 'suggestion', 'tip', 'lead', 'steer', 'confidential_information', 'wind', 'hint', 'hint', 'suggest']
#   Antonyms: []
# Word: 'computer'
#   Synonyms: ['computer', 'computing_machine', 'computing_device', 'data_processor', 'electronic_computer', 'information_processing_system', 'calculator', 'reckoner', 'figurer', 'estimator', 'computer']
#   Antonyms: []
# Word: 'significant'
#   Synonyms: ['significant', 'important', 'significant', 'substantial', 'significant', 'meaning', 'pregnant', 'significant']
#   Antonyms: ['insignificant', 'nonsignificant']
# Word: 'harness'
#   Synonyms: ['harness', 'harness', 'harness', 'tackle', 'harness', 'harness', 'rein_in', 'draw_rein', 'rein', 'rule', 'harness', 'rein']
#   Antonyms: ['unharness']
# Word: 'time'
#   Synonyms: ['time', 'clip', 'time', 'time', 'time', 'time', 'time', 'clock_time', 'time', 'fourth_dimension', 'time', 'meter', 'metre', 'time', 'prison_term', 'sentence', 'time', 'clock', 'time', 'time', 'time', 'time', 'time']
#   Antonyms: []
# Word: 'sophisticated'
#   Synonyms: ['sophisticate', 'twist', 'twist_around', 'pervert', 'convolute', 'sophisticate', 'sophisticate', 'doctor', 'doctor_up', 'sophisticate', 'sophisticated', 'advanced', 'sophisticated', 'sophisticated']
#   Antonyms: ['naive']
# Word: 'those'
#   Synonyms: []
#   Antonyms: []
# Word: 'monkeylearn'
#   Synonyms: []
#   Antonyms: []
# Word: 'text'
#   Synonyms: ['text', 'textual_matter', 'text', 'textbook', 'text', 'text_edition', 'schoolbook', 'school_text', 'text']
#   Antonyms: ['trade_edition']
# Word: 'findings'
#   Synonyms: ['findings', 'determination', 'finding', 'finding', 'finding', 'find', 'happen', 'chance', 'bump', 'encounter', 'detect', 'observe', 'find', 'discover', 'notice', 'find', 'regain', 'determine', 'find', 'find_out', 'ascertain', 'find', 'feel', 'witness', 'find', 'see', 'line_up', 'get_hold', 'come_up', 'find', 'discover', 'find', 'discover', 'find', 'find', 'rule', 'find', 'receive', 'get', 'find', 'obtain', 'incur', 'find', 'recover', 'retrieve', 'find', 'regain', 'find', 'find_oneself', 'find']
#   Antonyms: ['lose']
# Word: 'analyzed'
#   Synonyms: ['analyze', 'analyse', 'study', 'examine', 'canvass', 'canvas', 'analyze', 'analyse', 'break_down', 'dissect', 'take_apart', 'analyze', 'analyse', 'analyze', 'analyse', 'psychoanalyze', 'psychoanalyse', 'analyzed']
#   Antonyms: ['synthesize', 'unanalyzed']
# Word: 'modern'
#   Synonyms: ['modern', 'modern', 'modern_font', 'Bodoni', 'Bodoni_font', 'modern', 'mod', 'modern', 'modernistic', 'modern', 'advanced', 'forward-looking', 'innovative', 'modern', 'Modern', 'New']
#   Antonyms: ['old_style', 'nonmodern']
# Word: 'recognition'
#   Synonyms: ['recognition', 'acknowledgment', 'acknowledgement', 'recognition', 'identification', 'recognition', 'credit', 'realization', 'realisation', 'recognition', 'recognition', 'recognition', 'recognition', 'recognition']
#   Antonyms: []
# Word: 'simple'
#   Synonyms: ['simple', 'simpleton', 'simple', 'simple', 'elementary', 'simple', 'uncomplicated', 'unproblematic', 'bare', 'mere', 'simple', 'childlike', 'wide-eyed', 'round-eyed', 'dewy-eyed', 'simple', 'dim-witted', 'simple', 'simple-minded', 'simple', 'unsubdivided', 'simple']
#   Antonyms: ['complex', 'compound']
# Word: 'smaller'
#   Synonyms: ['smaller', 'littler', 'small', 'little', 'minor', 'modest', 'small', 'small-scale', 'pocket-size', 'pocket-sized', 'little', 'small', 'small', 'humble', 'low', 'lowly', 'modest', 'small', 'little', 'minuscule', 'small', 'little', 'small', 'small', 'modest', 'small', 'belittled', 'diminished', 'small']
#   Antonyms: ['large', 'big']
# Word: 'places'
#   Synonyms: ['topographic_point', 'place', 'spot', 'place', 'property', 'place', 'place', 'stead', 'position', 'place', 'lieu', 'place', 'shoes', 'home', 'place', 'position', 'post', 'berth', 'office', 'spot', 'billet', 'place', 'situation', 'position', 'place', 'place', 'station', 'seat', 'place', 'place', 'place', 'plaza', 'place', 'piazza', 'place', 'position', 'space', 'blank_space', 'place', 'put', 'set', 'place', 'pose', 'position', 'lay', 'place', 'rate', 'rank', 'range', 'order', 'grade', 'place', 'locate', 'place', 'site', 'place', 'place', 'come_in', 'come_out', 'target', 'aim', 'place', 'direct', 'point', 'identify', 'place', 'place', 'set', 'localize', 'localise', 'place', 'place', 'put', 'set', 'place', 'localize', 'localise', 'invest', 'put', 'commit', 'place', 'station', 'post', 'send', 'place', 'place', 'place']
#   Antonyms: ['divest']
# Word: 'day'
#   Synonyms: ['day', 'twenty-four_hours', 'twenty-four_hour_period', '24-hour_interval', 'solar_day', 'mean_solar_day', 'day', 'day', 'day', 'daytime', 'daylight', 'day', 'day', 'day', 'sidereal_day', 'day', 'day', 'Day', 'Clarence_Day', 'Clarence_Shepard_Day_Jr.']
#   Antonyms: ['night']
# Word: 'perceive'
#   Synonyms: ['perceive', 'comprehend', 'perceive']
#   Antonyms: []
# Word: 'researchers'
#   Synonyms: ['research_worker', 'researcher', 'investigator']
#   Antonyms: []
# Word: 'analyze'
#   Synonyms: ['analyze', 'analyse', 'study', 'examine', 'canvass', 'canvas', 'analyze', 'analyse', 'break_down', 'dissect', 'take_apart', 'analyze', 'analyse', 'analyze', 'analyse', 'psychoanalyze', 'psychoanalyse']
#   Antonyms: ['synthesize']
# Word: 'further'
#   Synonyms: ['foster', 'further', 'promote', 'advance', 'boost', 'further', 'encourage', 'further', 'farther', 'further', 'farther', 'further', 'farther', 'further', 'far', 'far', 'far', 'far', 'far']
#   Antonyms: []
# Word: 'algorithms'
#   Synonyms: ['algorithm', 'algorithmic_rule', 'algorithmic_program']
#   Antonyms: []
# Word: 'legal'
#   Synonyms: ['legal', 'legal', 'legal', 'sound', 'effectual', 'legal', 'legal']
#   Antonyms: ['illegal']
# Word: 'provide'
#   Synonyms: ['supply', 'provide', 'render', 'furnish', 'provide', 'supply', 'ply', 'cater', 'provide', 'put_up', 'provide', 'offer', 'leave', 'allow_for', 'allow', 'provide', 'provide', 'bring_home_the_bacon', 'provide']
#   Antonyms: []
# Word: 'media'
#   Synonyms: ['medium', 'medium', 'medium', 'culture_medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'medium', 'spiritualist', 'sensitive', 'medium', 'mass_medium', 'metier', 'medium']
#   Antonyms: []
# Word: 'delight'
#   Synonyms: ['delight', 'delectation', 'joy', 'delight', 'pleasure', 'please', 'delight', 'delight', 'enjoy', 'revel', 'enchant', 'enrapture', 'transport', 'enthrall', 'ravish', 'enthral', 'delight']
#   Antonyms: ['displease', 'disenchant']
# Word: 'toolkit'
#   Synonyms: []
#   Antonyms: []
# Word: 'awful'
#   Synonyms: ['atrocious', 'abominable', 'awful', 'dreadful', 'painful', 'terrible', 'unspeakable', 'awful', 'dire', 'direful', 'dread', 'dreaded', 'dreadful', 'fearful', 'fearsome', 'frightening', 'horrendous', 'horrific', 'terrible', 'nasty', 'awful', 'awed', 'awful', 'frightful', 'terrible', 'awful', 'tremendous', 'amazing', 'awe-inspiring', 'awesome', 'awful', 'awing', 'terribly', 'awfully', 'awful', 'frightfully']
#   Antonyms: ['nice']
# Word: 'actionable'
#   Synonyms: ['actionable']
#   Antonyms: []
# Word: 'object'
#   Synonyms: ['object', 'physical_object', 'aim', 'object', 'objective', 'target', 'object', 'object', 'object', 'object', 'object']
#   Antonyms: []
# Word: 'relationships'
#   Synonyms: ['relationship', 'human_relationship', 'relationship', 'relationship', 'kinship', 'family_relationship', 'relationship']
#   Antonyms: []
# Word: 'established'
#   Synonyms: ['establish', 'set_up', 'found', 'launch', 'establish', 'found', 'plant', 'constitute', 'institute', 'prove', 'demonstrate', 'establish', 'show', 'shew', 'lay_down', 'establish', 'make', 'establish', 'give', 'install', 'instal', 'set_up', 'establish', 'build', 'establish', 'establish', 'base', 'ground', 'found', 'established', 'constituted', 'accomplished', 'effected', 'established', 'conventional', 'established', 'established', 'established', 'naturalized']
#   Antonyms: ['abolish', 'disprove', 'unestablished']
# Word: 'hit'
#   Synonyms: ['hit', 'hit', 'hitting', 'striking', 'hit', 'smash', 'smasher', 'strike', 'bang', 'collision', 'hit', 'hit', 'hit', 'hit', 'hit', 'hit', 'strike', 'impinge_on', 'run_into', 'collide_with', 'hit', 'reach', 'make', 'attain', 'hit', 'arrive_at', 'gain', 'hit', 'strike', 'shoot', 'hit', 'pip', 'stumble', 'hit', 'score', 'hit', 'tally', 'rack_up', 'hit', 'strike', 'come_to', 'strike', 'hit', 'murder', 'slay', 'hit', 'dispatch', 'bump_off', 'off', 'polish_off', 'remove', 'hit', 'strike', 'reach', 'hit', 'attain', 'strike', 'hit', 'hit', 'hit', 'hit']
#   Antonyms: ['miss']
# Word: 'providing'
#   Synonyms: ['supply', 'provide', 'render', 'furnish', 'provide', 'supply', 'ply', 'cater', 'provide', 'put_up', 'provide', 'offer', 'leave', 'allow_for', 'allow', 'provide', 'provide', 'bring_home_the_bacon', 'provide']
#   Antonyms: []
# Word: 'used'
#   Synonyms: ['use', 'utilize', 'utilise', 'apply', 'employ', 'use', 'habituate', 'use', 'expend', 'use', 'practice', 'apply', 'use', 'use', 'used', 'exploited', 'ill-used', 'put-upon', 'used', 'victimized', 'victimised', 'secondhand', 'used']
#   Antonyms: ['misused']
# Word: 'marketing'
#   Synonyms: ['selling', 'merchandising', 'marketing', 'marketing', 'marketing', 'market', 'market', 'market', 'commercialize', 'commercialise', 'market']
#   Antonyms: []
# Word: 'referred'
#   Synonyms: ['mention', 'advert', 'bring_up', 'cite', 'name', 'refer', 'refer', 'pertain', 'relate', 'concern', 'come_to', 'bear_on', 'touch', 'touch_on', 'have-to_doe_with', 'refer', 'refer', 'consult', 'refer', 'look_up', 'denote', 'refer', 'refer']
#   Antonyms: []
# Word: 'technique'
#   Synonyms: ['technique', 'proficiency', 'technique']
#   Antonyms: []
# Word: 'implementation'
#   Synonyms: ['execution', 'implementation', 'carrying_out', 'implementation', 'effectuation']
#   Antonyms: []
# Word: 'retrieval'
#   Synonyms: ['retrieval', 'retrieval', 'recovery', 'retrieval']
#   Antonyms: []
# Word: 'can'
#   Synonyms: ['can', 'tin', 'tin_can', 'can', 'canful', 'can', 'can_buoy', 'buttocks', 'nates', 'arse', 'butt', 'backside', 'bum', 'buns', 'can', 'fundament', 'hindquarters', 'hind_end', 'keister', 'posterior', 'prat', 'rear', 'rear_end', 'rump', 'stern', 'seat', 'tail', 'tail_end', 'tooshie', 'tush', 'bottom', 'behind', 'derriere', 'fanny', 'ass', 'toilet', 'can', 'commode', 'crapper', 'pot', 'potty', 'stool', 'throne', 'toilet', 'lavatory', 'lav', 'can', 'john', 'privy', 'bathroom', 'can', 'tin', 'put_up', 'displace', 'fire', 'give_notice', 'can', 'dismiss', 'give_the_axe', 'send_away', 'sack', 'force_out', 'give_the_sack', 'terminate']
#   Antonyms: ['hire']
# Word: 'into'
#   Synonyms: []
#   Antonyms: []
# Word: 'it'
#   Synonyms: ['information_technology', 'IT']
#   Antonyms: []
# Word: 'applicable'
#   Synonyms: ['applicable']
#   Antonyms: []
# Word: 'systematic'
#   Synonyms: ['systematic', 'taxonomic', 'taxonomical', 'systematic']
#   Antonyms: ['unsystematic']
# Word: 'evaluation'
#   Synonyms: ['evaluation', 'rating', 'evaluation', 'valuation', 'rating']
#   Antonyms: []
# Word: 'assisting'
#   Synonyms: ['help', 'assist', 'aid', 'assist', 'serve', 'attend_to', 'wait_on', 'attend', 'assist']
#   Antonyms: []
# Word: 'sentences'
#   Synonyms: ['sentence', 'conviction', 'judgment_of_conviction', 'condemnation', 'sentence', 'prison_term', 'sentence', 'time', 'sentence', 'condemn', 'doom']
#   Antonyms: ['acquittal']
# Word: 'preprocessing'
#   Synonyms: []
#   Antonyms: []
# Word: 'gauge'
#   Synonyms: ['gauge', 'gage', 'gauge', 'standard_of_measurement', 'gauge', 'gauge', 'bore', 'gauge', 'caliber', 'calibre', 'estimate', 'gauge', 'approximate', 'guess', 'judge', 'gauge', 'gauge', 'gauge', 'gauge', 'gauge']
#   Antonyms: []
# Word: 'product'
#   Synonyms: ['merchandise', 'ware', 'product', 'product', 'production', 'product', 'mathematical_product', 'product', 'product', 'intersection', 'product', 'Cartesian_product']
#   Antonyms: []
# Word: 'groups'
#   Synonyms: ['group', 'grouping', 'group', 'radical', 'chemical_group', 'group', 'mathematical_group', 'group', 'group', 'aggroup']
#   Antonyms: []
# Word: 'contracts'
#   Synonyms: ['contract', 'contract', 'declaration', 'contract', 'contract_bridge', 'contract', 'undertake', 'sign', 'contract', 'sign_on', 'sign_up', 'compress', 'constrict', 'squeeze', 'compact', 'contract', 'press', 'contract', 'take', 'get', 'shrink', 'contract', 'contract', 'condense', 'concentrate', 'contract', 'narrow', 'contract', 'abridge', 'foreshorten', 'abbreviate', 'shorten', 'cut', 'contract', 'reduce']
#   Antonyms: ['stretch', 'expand', 'widen', 'expand']
# Word: 'patron'
#   Synonyms: ['patron', 'frequenter', 'patron', 'patron', 'sponsor', 'supporter']
#   Antonyms: []
# Word: 'usage'
#   Synonyms: ['use', 'usage', 'utilization', 'utilisation', 'employment', 'exercise', 'custom', 'usage', 'usance', 'usage']
#   Antonyms: []
# Word: 'activities'
#   Synonyms: ['activity', 'action', 'activity', 'activeness', 'bodily_process', 'body_process', 'bodily_function', 'activity', 'activity', 'natural_process', 'natural_action', 'action', 'activity', 'activeness', 'activity']
#   Antonyms: ['inactivity', 'inaction', 'inactivity', 'inactiveness', 'inactiveness']
# Word: 'learning'
#   Synonyms: ['learning', 'acquisition', 'eruditeness', 'erudition', 'learnedness', 'learning', 'scholarship', 'encyclopedism', 'encyclopaedism', 'learn', 'larn', 'acquire', 'learn', 'hear', 'get_word', 'get_wind', 'pick_up', 'find_out', 'get_a_line', 'discover', 'see', 'memorize', 'memorise', 'con', 'learn', 'learn', 'study', 'read', 'take', 'teach', 'learn', 'instruct', 'determine', 'check', 'find_out', 'see', 'ascertain', 'watch', 'learn']
#   Antonyms: []
# Word: 'introduction'
#   Synonyms: ['introduction', 'debut', 'first_appearance', 'launching', 'unveiling', 'entry', 'introduction', 'presentation', 'introduction', 'intro', 'introduction', 'introduction', 'insertion', 'introduction', 'intromission', 'initiation', 'founding', 'foundation', 'institution', 'origination', 'creation', 'innovation', 'introduction', 'instauration']
#   Antonyms: []
# Word: 'prison'
#   Synonyms: ['prison', 'prison_house', 'prison', 'prison_house']
#   Antonyms: []
# Word: 'safety'
#   Synonyms: ['safety', 'safety', 'refuge', 'guard', 'safety', 'safety_device', 'base_hit', 'safety', 'condom', 'rubber', 'safety', 'safe', 'prophylactic', 'safety']
#   Antonyms: ['danger']
# Word: 'clustering'
#   Synonyms: ['bunch', 'clump', 'cluster', 'clustering', 'cluster', 'constellate', 'flock', 'clump', 'bunch', 'bunch_up', 'bundle', 'cluster', 'clump']
#   Antonyms: []
# Word: 'spacy'
#   Synonyms: ['spaced-out', 'spacy', 'spacey']
#   Antonyms: []
# Word: 'includes'
#   Synonyms: ['include', 'include', 'include', 'admit', 'let_in', 'include']
#   Antonyms: ['exclude', 'exclude', 'exclude']
# Word: 'hidden'
#   Synonyms: ['hide', 'conceal', 'hide', 'hide_out', 'shroud', 'enshroud', 'hide', 'cover', 'obscure', 'blot_out', 'obliterate', 'veil', 'hide', 'concealed', 'hidden', 'out_of_sight', 'hidden', 'secret', 'hidden', 'obscure']
#   Antonyms: ['show']
# Word: 'choices'
#   Synonyms: ['choice', 'pick', 'selection', 'choice', 'selection', 'option', 'pick', 'option', 'alternative', 'choice']
#   Antonyms: []
# Word: 'corpus'
#   Synonyms: ['principal', 'corpus', 'principal_sum', 'corpus', 'corpus']
#   Antonyms: []
# Word: 'unstructured'
#   Synonyms: ['unstructured', 'amorphous', 'unstructured']
#   Antonyms: ['structured']
# Word: 'out'
#   Synonyms: ['out', 'come_out_of_the_closet', 'out', 'come_out', 'out', 'out', 'come_out', 'out', 'extinct', 'out', 'out', 'out', 'forbidden', 'out', 'prohibited', 'proscribed', 'taboo', 'tabu', 'verboten', 'out', 'out', 'out', 'out', 'knocked_out', 'kayoed', "KO'd", 'out', 'stunned', 'out', 'out', 'away', 'out']
#   Antonyms: ['safe']
# Word: 'fraud'
#   Synonyms: ['fraud', 'imposter', 'impostor', 'pretender', 'fake', 'faker', 'fraud', 'sham', 'shammer', 'pseudo', 'pseud', 'role_player', 'fraud', 'fraudulence', 'dupery', 'hoax', 'humbug', 'put-on']
#   Antonyms: []
# Word: 'a'
#   Synonyms: ['angstrom', 'angstrom_unit', 'A', 'vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A', 'deoxyadenosine_monophosphate', 'A', 'adenine', 'A', 'ampere', 'amp', 'A', 'A', 'a', 'A', 'type_A', 'group_A']
#   Antonyms: []
# Word: 'as'
#   Synonyms: ['arsenic', 'As', 'atomic_number_33', 'American_Samoa', 'Eastern_Samoa', 'AS', 'angstrom', 'angstrom_unit', 'A', 'vitamin_A', 'antiophthalmic_factor', 'axerophthol', 'A', 'deoxyadenosine_monophosphate', 'A', 'adenine', 'A', 'ampere', 'amp', 'A', 'A', 'a', 'A', 'type_A', 'group_A', 'equally', 'as', 'every_bit']
#   Antonyms: []
# Word: 'quantified'
#   Synonyms: ['quantify', 'quantify', 'measure']
#   Antonyms: []
# Word: 'opennlp'
#   Synonyms: []
#   Antonyms: []
# Word: 'opinion'
#   Synonyms: ['opinion', 'sentiment', 'persuasion', 'view', 'thought', 'opinion', 'view', 'public_opinion', 'popular_opinion', 'opinion', 'vox_populi', 'opinion', 'legal_opinion', 'judgment', 'judgement', 'opinion', 'ruling', 'impression', 'feeling', 'belief', 'notion', 'opinion']
#   Antonyms: []
# Word: 'primarily'
#   Synonyms: ['chiefly', 'principally', 'primarily', 'mainly', 'in_the_main', 'primarily', 'in_the_first_place']
#   Antonyms: ['secondarily']
# Word: 'one'
#   Synonyms: ['one', '1', 'I', 'ace', 'single', 'unity', 'one', 'one', '1', 'i', 'ane', 'one', 'unitary', 'one', 'one', 'one', 'one', 'matchless', 'nonpareil', 'one', 'one_and_only', 'peerless', 'unmatched', 'unmatchable', 'unrivaled', 'unrivalled']
#   Antonyms: []
# Word: 'remodeling'
#   Synonyms: ['remodel', 'reconstruct', 'redo', 'recast', 'reforge', 'remodel']
#   Antonyms: []
# Word: 'affected'
#   Synonyms: ['affect', 'impact', 'bear_upon', 'bear_on', 'touch_on', 'touch', 'affect', 'involve', 'affect', 'regard', 'feign', 'sham', 'pretend', 'affect', 'dissemble', 'affect', 'impress', 'move', 'strike', 'affected', 'affected', 'unnatural', 'moved', 'affected', 'stirred', 'touched']
#   Antonyms: ['unaffected', 'unaffected', 'unmoved']
# Word: 'nltk'
#   Synonyms: []
#   Antonyms: []
# Word: 'tokens'
#   Synonyms: ['token', 'item', 'token', 'token', 'keepsake', 'souvenir', 'token', 'relic']
#   Antonyms: []
# Word: 'screen'
#   Synonyms: ['screen', 'silver_screen', 'projection_screen', 'blind', 'screen', 'screen', 'CRT_screen', 'screen', 'cover', 'covert', 'concealment', 'screen', 'filmdom', 'screenland', 'screen', 'sieve', 'screen', 'screen_door', 'screen', 'screen', 'screen', 'test', 'screen', 'screen', 'screen_out', 'sieve', 'sort', 'screen', 'screen', 'block_out', 'riddle', 'screen', 'shield', 'screen']
#   Antonyms: []
# Word: 'thereby'
#   Synonyms: ['thereby']
#   Antonyms: []
# Word: 'of'
#   Synonyms: []
#   Antonyms: []
# Word: 'trending'
#   Synonyms: ['swerve', 'sheer', 'curve', 'trend', 'veer', 'slue', 'slew', 'cut']
#   Antonyms: []
# Word: 'breaking'
#   Synonyms: ['breakage', 'break', 'breaking', 'interrupt', 'break', 'break', 'separate', 'split_up', 'fall_apart', 'come_apart', 'break', 'break', 'bust', 'break', 'transgress', 'offend', 'infract', 'violate', 'go_against', 'breach', 'break', 'break', 'break_out', 'break_away', 'break', 'break', 'burst', 'erupt', 'break', 'break_off', 'discontinue', 'stop', 'break_in', 'break', 'break_in', 'break', 'violate', 'go_against', 'break', 'better', 'break', 'unwrap', 'disclose', 'let_on', 'bring_out', 'reveal', 'discover', 'expose', 'divulge', 'break', 'give_away', 'let_out', 'break', 'fail', 'go_bad', 'give_way', 'die', 'give_out', 'conk_out', 'go', 'break', 'break_down', 'break', 'break_away', 'break', 'break', 'dampen', 'damp', 'soften', 'weaken', 'break', 'break', 'break', 'break', 'break', 'break', 'break', 'break', 'break', 'break', 'separate', 'part', 'split_up', 'split', 'break', 'break_up', 'demote', 'bump', 'relegate', 'break', 'kick_downstairs', 'bankrupt', 'ruin', 'break', 'smash', 'break', 'break', 'collapse', 'fall_in', 'cave_in', 'give', 'give_way', 'break', 'founder', 'break_dance', 'break-dance', 'break', 'break', 'break', 'break_up', 'break', 'break', 'break', 'wear', 'wear_out', 'bust', 'fall_apart', 'break', 'break_off', 'snap_off', 'break', 'break', 'break', 'get_out', 'get_around', 'pause', 'intermit', 'break', 'break', 'break', 'break', 'break', 'break', 'break', 'recrudesce', 'develop', 'crack', 'check', 'break', 'break', 'break', 'fracture', 'break', 'break', 'break']
#   Antonyms: ['repair', 'keep', 'conform_to', 'make', 'promote']
# Word: 'crimes'
#   Synonyms: ['crime', 'offense', 'criminal_offense', 'criminal_offence', 'offence', 'law-breaking', 'crime']
#   Antonyms: []
# Word: 'assist'
#   Synonyms: ['aid', 'assist', 'assistance', 'help', 'assist', 'help', 'assist', 'aid', 'assist', 'serve', 'attend_to', 'wait_on', 'attend', 'assist']
#   Antonyms: []
# Word: 'grammatical'
#   Synonyms: ['grammatical', 'grammatic', 'grammatical', 'well-formed']
#   Antonyms: ['ungrammatical']
# Word: 'data'
#   Synonyms: ['data', 'information', 'datum', 'data_point']
#   Antonyms: []
# Word: 'lexalytics'
#   Synonyms: []
#   Antonyms: []
# Word: 'these'
#   Synonyms: []
#   Antonyms: []
# Word: 'transactional'
#   Synonyms: []
#   Antonyms: []
# Word: 'predictions'
#   Synonyms: ['prediction', 'anticipation', 'prevision', 'prediction', 'foretelling', 'forecasting', 'prognostication']
#   Antonyms: []
# Word: 'allows'
#   Synonyms: ['let', 'allow', 'permit', 'permit', 'allow', 'let', 'countenance', 'allow', 'grant', 'allow', 'appropriate', 'earmark', 'set_aside', 'reserve', 'leave', 'allow_for', 'allow', 'provide', 'allow', 'take_into_account', 'admit', 'allow', 'give_up', 'allow', 'allow', 'allow', 'permit', 'tolerate']
#   Antonyms: ['prevent', 'forbid', 'disallow', 'deny']
# Word: 'patterns'
#   Synonyms: ['form', 'shape', 'pattern', 'practice', 'pattern', 'design', 'pattern', 'figure', 'convention', 'normal', 'pattern', 'rule', 'formula', 'pattern', 'blueprint', 'design', 'pattern', 'traffic_pattern', 'approach_pattern', 'pattern', 'radiation_pattern', 'radiation_diagram', 'pattern', 'model', 'pattern', 'pattern']
#   Antonyms: []
# Word: 'development'
#   Synonyms: ['development', 'development', 'evolution', 'growth', 'growing', 'maturation', 'development', 'ontogeny', 'ontogenesis', 'development', 'exploitation', 'development', 'development', 'development', 'development', 'developing', 'development']
#   Antonyms: ['devolution', 'nondevelopment']
# Word: 'computational'
#   Synonyms: ['computational']
#   Antonyms: []
# Word: 'expressed'
#   Synonyms: ['express', 'show', 'evince', 'express', 'verbalize', 'verbalise', 'utter', 'give_tongue_to', 'carry', 'convey', 'express', 'express', 'state', 'express', 'press_out', 'express', 'extract', 'express', 'expressed', 'uttered', 'verbalized', 'verbalised', 'explicit', 'expressed']
#   Antonyms: ['implicit']
# Word: 'healthcare'
#   Synonyms: ['healthcare', 'health_care']
#   Antonyms: []
# Word: 'impartial'
#   Synonyms: ['impartial', 'unprejudiced', 'impartial']
#   Antonyms: ['partial', 'prejudiced']
# Word: 'permits'
#   Synonyms: ['license', 'licence', 'permit', 'license', 'permission', 'permit', 'permit', 'Trachinotus_falcatus', 'permit', 'allow', 'let', 'countenance', 'let', 'allow', 'permit', 'allow', 'permit', 'tolerate']
#   Antonyms: ['forbid', 'disallow', 'prevent']
# Word: 'benefit'
#   Synonyms: ['benefit', 'benefit', 'welfare', 'benefit', 'profit', 'gain', 'benefit', 'benefit', 'do_good']
#   Antonyms: []
# Word: 'or'
#   Synonyms: ['Oregon', 'Beaver_State', 'OR', 'operating_room', 'OR', 'operating_theater', 'operating_theatre', 'surgery']
#   Antonyms: []
# Word: 'companies'
#   Synonyms: ['company', 'company', 'company', 'companionship', 'fellowship', 'society', 'company', 'troupe', 'caller', 'company', 'company', 'party', 'company', "ship's_company", 'company', 'company', 'company', 'companion', 'accompany', 'keep_company']
#   Antonyms: []
# Word: 'facilitates'
#   Synonyms: ['facilitate', 'ease', 'alleviate', 'help', 'facilitate', 'facilitate']
#   Antonyms: []
# Word: 'frameworks'
#   Synonyms: ['model', 'theoretical_account', 'framework', 'framework', 'fabric', 'framework']
#   Antonyms: []
# Word: 'components'
#   Synonyms: ['component', 'constituent', 'element', 'factor', 'ingredient', 'part', 'portion', 'component_part', 'component', 'constituent', 'component', 'constituent', 'element']
#   Antonyms: []
# Word: 'different'
#   Synonyms: ['different', 'different', 'different', 'unlike', 'dissimilar', 'different', 'different']
#   Antonyms: ['same', 'like']
# Word: 'information'
#   Synonyms: ['information', 'info', 'information', 'information', 'data', 'information', 'information', 'selective_information', 'entropy']
#   Antonyms: []
# Word: 'modeling'
#   Synonyms: ['mold', 'mould', 'molding', 'moulding', 'modeling', 'clay_sculpture', 'modeling', 'modelling', 'molding', 'moulding', 'model', 'modelling', 'modeling', 'model', 'pattern', 'model', 'mold', 'mould', 'model', 'pose', 'sit', 'posture', 'model', 'model', 'simulate', 'model', 'mock_up']
#   Antonyms: []
# Word: 'artificial'
#   Synonyms: ['artificial', 'unreal', 'artificial', 'contrived', 'hokey', 'stilted', 'artificial']
#   Antonyms: ['natural']
# Word: 'advertising'
#   Synonyms: ['ad', 'advertisement', 'advertizement', 'advertising', 'advertizing', 'advert', 'advertising', 'publicizing', 'advertise', 'publicize', 'advertize', 'publicise', 'advertise', 'advertize', 'promote', 'push']
#   Antonyms: []
# Word: 'improvement'
#   Synonyms: ['improvement', 'betterment', 'advance', 'improvement', 'improvement', 'melioration']
#   Antonyms: ['decline']
# Word: 'statistics'
#   Synonyms: ['statistics', 'statistic']
#   Antonyms: []
# Word: 'classifies'
#   Synonyms: ['classify', 'class', 'sort', 'assort', 'sort_out', 'separate', 'classify', 'relegate', 'classify']
#   Antonyms: ['declassify']
# Word: 'techniques'
#   Synonyms: ['technique', 'proficiency', 'technique']
#   Antonyms: []
# Word: 'analysis'
#   Synonyms: ['analysis', 'analysis', 'analytic_thinking', 'analysis', 'analysis', 'analysis', 'psychoanalysis', 'analysis', 'depth_psychology']
#   Antonyms: ['synthesis']
# Word: 'agency'
#   Synonyms: ['agency', 'federal_agency', 'government_agency', 'bureau', 'office', 'authority', 'agency', 'agency', 'representation', 'delegacy', 'agency', 'means', 'agency', 'way']
#   Antonyms: []
# Word: 'based'
#   Synonyms: ['establish', 'base', 'ground', 'found', 'base', 'free-base', 'base', 'based', 'based']
#   Antonyms: []
# Word: 'use'
#   Synonyms: ['use', 'usage', 'utilization', 'utilisation', 'employment', 'exercise', 'function', 'purpose', 'role', 'use', 'use', 'consumption', 'economic_consumption', 'usance', 'use', 'use_of_goods_and_services', 'habit', 'use', 'manipulation', 'use', 'use', 'enjoyment', 'use', 'utilize', 'utilise', 'apply', 'employ', 'use', 'habituate', 'use', 'expend', 'use', 'practice', 'apply', 'use', 'use']
#   Antonyms: []
# Word: 'internal'
#   Synonyms: ['internal', 'internal', 'intragroup', 'home', 'interior', 'internal', 'national', 'inner', 'interior', 'internal', 'inner', 'internal', 'intimate']
# ...
#   Antonyms: ['synthesize']
# Word: 'names'
#   Synonyms: ['name_calling', 'names', 'name', 'name', 'name', 'gens', 'name', 'figure', 'public_figure', 'name', 'name', 'epithet', 'name', 'call', 'name', 'identify', 'name', 'nominate', 'make', 'appoint', 'name', 'nominate', 'constitute', 'name', 'mention', 'advert', 'bring_up', 'cite', 'name', 'refer', 'identify', 'discover', 'key', 'key_out', 'distinguish', 'describe', 'name', 'list', 'name', 'diagnose', 'name']
#   Antonyms: []
# Word: 'chain'
#   Synonyms: ['chain', 'concatenation', 'chain', 'chemical_chain', 'chain', 'chain', 'chain', 'chain', 'Chain', 'Ernst_Boris_Chain', 'Sir_Ernst_Boris_Chain', 'range', 'mountain_range', 'range_of_mountains', 'chain', 'mountain_chain', 'chain_of_mountains', 'chain', 'chain', 'string', 'strand', 'chain', 'chain']
#   Antonyms: ['unchain']
# Word: 'examine'
#   Synonyms: ['analyze', 'analyse', 'study', 'examine', 'canvass', 'canvas', 'examine', 'see', 'probe', 'examine', 'examine', 'test', 'prove', 'try', 'try_out', 'examine', 'essay']
#   Antonyms: []
# Word: 'records'
#   Synonyms: ['record', 'phonograph_record', 'phonograph_recording', 'record', 'disk', 'disc', 'platter', 'record', 'record', 'track_record', 'record', 'record_book', 'book', 'record', 'record', 'criminal_record', 'record', 'record', 'enter', 'put_down', 'record', 'tape', 'read', 'register', 'show', 'record', 'record', 'register', 'commemorate', 'memorialize', 'memorialise', 'immortalize', 'immortalise', 'record']
#   Antonyms: ['erase']
# Word: 'technologies'
#   Synonyms: ['technology', 'engineering', 'engineering', 'engineering_science', 'applied_science', 'technology']
#   Antonyms: []
# Word: 'definition'
#   Synonyms: ['definition', 'definition']
#   Antonyms: []
# Word: 'topics'
#   Synonyms: ['subject', 'topic', 'theme', 'topic', 'subject', 'issue', 'matter']
#   Antonyms: []
# Word: 'client'
#   Synonyms: ['client', 'customer', 'client', 'node', 'client', 'guest']
#   Antonyms: []
# Word: 'clinical'
#   Synonyms: ['clinical', 'clinical']
#   Antonyms: []
# Word: 'structures'
#   Synonyms: ['structure', 'construction', 'structure', 'structure', 'structure', 'anatomical_structure', 'complex_body_part', 'bodily_structure', 'body_structure', 'social_organization', 'social_organisation', 'social_structure', 'social_system', 'structure', 'structure']
#   Antonyms: []
# Word: 'crook'
#   Synonyms: ['criminal', 'felon', 'crook', 'outlaw', 'malefactor', 'bend', 'crook', 'twist', 'turn', 'crook', "shepherd's_crook", 'crook', 'curve']
#   Antonyms: []
# Word: 'gear'
#   Synonyms: ['gear', 'gear_wheel', 'geared_wheel', 'cogwheel', 'gearing', 'gear', 'geartrain', 'power_train', 'train', 'gear', 'gear_mechanism', 'gear', 'paraphernalia', 'appurtenance', 'gear', 'pitch']
#   Antonyms: []
# Word: 'enterprise'
#   Synonyms: ['enterprise', 'endeavor', 'endeavour', 'enterprise', 'enterprise', 'enterprisingness', 'initiative', 'go-ahead']
#   Antonyms: []
# Word: 'law'
#   Synonyms: ['law', 'jurisprudence', 'law', 'law', 'natural_law', 'law', 'law_of_nature', 'jurisprudence', 'law', 'legal_philosophy', 'law', 'practice_of_law', 'police', 'police_force', 'constabulary', 'law']
#   Antonyms: []
# Word: 'are'
#   Synonyms: ['are', 'ar', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make_up', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
#   Antonyms: ['differ']
# Word: 'pushed'
#   Synonyms: ['push', 'force', 'push', 'bear_on', 'advertise', 'advertize', 'promote', 'push', 'tug', 'labor', 'labour', 'push', 'drive', 'push', 'push', 'crowd', 'crusade', 'fight', 'press', 'campaign', 'push', 'agitate', 'push', 'push', 'press', 'push']
#   Antonyms: ['pull']
# Word: 'back'
#   Synonyms: ['back', 'dorsum', 'rear', 'back', 'back', 'rear', 'back', 'spinal_column', 'vertebral_column', 'spine', 'backbone', 'back', 'rachis', 'binding', 'book_binding', 'cover', 'back', 'back', 'back', 'backrest', 'back', 'back', 'endorse', 'indorse', 'plump_for', 'plunk_for', 'support', 'back', 'second', 'back', 'endorse', 'indorse', 'back', 'back', 'back', 'bet_on', 'back', 'gage', 'stake', 'game', 'punt', 'back', 'back', 'back_up', 'back', 'back', 'back', 'hind', 'hinder', 'back', 'back', 'back', 'backward', 'backwards', 'rearward', 'rearwards', 'back', 'back', 'backward', 'back', 'back']
#   Antonyms: ['front', 'front', 'advance', 'front', 'veer', 'front', 'forward', 'ahead', 'forward']
# Word: 'be'
#   Synonyms: ['beryllium', 'Be', 'glucinium', 'atomic_number_4', 'be', 'be', 'be', 'exist', 'be', 'be', 'equal', 'be', 'constitute', 'represent', 'make_up', 'comprise', 'be', 'be', 'follow', 'embody', 'be', 'personify', 'be', 'be', 'live', 'be', 'cost', 'be']
#   Antonyms: ['differ']
# Word: 'parsing'
#   Synonyms: ['parse']
#   Antonyms: []
# Word: 'knowledge'
#   Synonyms: ['cognition', 'knowledge', 'noesis']
#   Antonyms: []
# Word: 'to'
#   Synonyms: []
#   Antonyms: []
# Word: 'commercial'
#   Synonyms: ['commercial', 'commercial_message', 'commercial', 'commercial', 'commercial', 'commercial-grade']
#   Antonyms: ['noncommercial']
# Word: 'methodologies'
#   Synonyms: ['methodology', 'methodological_analysis', 'methodology']
#   Antonyms: []
# Word: 'step'
#   Synonyms: ['measure', 'step', 'footstep', 'pace', 'step', 'stride', 'step', 'step', 'stair', 'gradation', 'step', 'step', "stone's_throw", 'footfall', 'footstep', 'step', 'tone', 'whole_tone', 'step', 'whole_step', 'footprint', 'footmark', 'step', 'step', 'dance_step', 'step', 'step', 'step', 'tread', 'step', 'mistreat', 'maltreat', 'abuse', 'ill-use', 'step', 'ill-treat', 'step', 'step', 'step', 'step', 'pace', 'step', 'step']
#   Antonyms: []
# Word: 'determines'
#   Synonyms: ['determine', 'find', 'find_out', 'ascertain', 'determine', 'shape', 'mold', 'influence', 'regulate', 'determine', 'set', 'specify', 'set', 'determine', 'define', 'fix', 'limit', 'decide', "make_up_one's_mind", 'determine', 'determine', 'settle', 'square_off', 'square_up', 'determine', 'determine', 'check', 'find_out', 'see', 'ascertain', 'watch', 'learn']
#   Antonyms: []
# Word: 'identifying'
#   Synonyms: ['identify', 'place', 'name', 'identify', 'identify', 'identify', 'identify', 'discover', 'key', 'key_out', 'distinguish', 'describe', 'name', 'identify']
#   Antonyms: []
# Word: 'massive'
#   Synonyms: ['massive', 'monolithic', 'monumental', 'massive', 'massive', 'massive']
#   Antonyms: []
# Word: 'utilizes'
#   Synonyms: ['use', 'utilize', 'utilise', 'apply', 'employ', 'utilize']
#   Antonyms: []
# Word: 'gaining'
#   Synonyms: ['derive', 'gain', 'acquire', 'win', 'gain', 'profit', 'gain', 'benefit', 'reach', 'make', 'attain', 'hit', 'arrive_at', 'gain', 'gain', 'advance', 'win', 'pull_ahead', 'make_headway', 'get_ahead', 'gain_ground', 'advance', 'gain', 'gain', 'gather', 'gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in', 'gain', 'put_on']
#   Antonyms: ['lose', 'fall_back', 'reduce']
# Word: 'intelligence'
#   Synonyms: ['intelligence', 'intelligence', 'intelligence_service', 'intelligence_agency', 'intelligence', 'intelligence_information', 'news', 'intelligence', 'tidings', 'word', 'intelligence', 'intelligence_activity', 'intelligence_operation']
#   Antonyms: ['stupidity']
# Word: 'in'
#   Synonyms: ['inch', 'in', 'indium', 'In', 'atomic_number_49', 'Indiana', 'Hoosier_State', 'IN', 'in', 'in', 'in', 'in', 'inwards', 'inward']
#   Antonyms: []
# Word: 'generate'
#   Synonyms: ['generate', 'bring_forth', 'render', 'yield', 'return', 'give', 'generate', 'generate', 'beget', 'get', 'engender', 'father', 'mother', 'sire', 'generate', 'bring_forth']
#   Antonyms: []
# Word: 'world'
#   Synonyms: ['universe', 'existence', 'creation', 'world', 'cosmos', 'macrocosm', 'world', 'domain', 'world', 'reality', 'Earth', 'earth', 'world', 'globe', 'populace', 'public', 'world', 'world', 'worldly_concern', 'earthly_concern', 'world', 'earth', 'world', 'human_race', 'humanity', 'humankind', 'human_beings', 'humans', 'mankind', 'man', 'global', 'planetary', 'world', 'worldwide', 'world-wide']
#   Antonyms: []
# Word: 'that'
#   Synonyms: []
#   Antonyms: []
# Word: 'tools'
#   Synonyms: ['tool', 'instrument', 'tool', 'creature', 'tool', 'puppet', 'cock', 'prick', 'dick', 'shaft', 'pecker', 'peter', 'tool', 'putz', 'tool', 'joyride', 'tool', 'tool_around', 'tool', 'tool']
#   Antonyms: []
# Word: 'deriving'
#   Synonyms: ['deriving', 'derivation', 'etymologizing', 'deduce', 'infer', 'deduct', 'derive', 'derive', 'gain', 'derive', 'derive', 'educe', 'derive', 'come', 'descend']
#   Antonyms: []
# Word: 'deciphering'
#   Synonyms: ['decode', 'decrypt', 'decipher', 'decipher', 'trace']
#   Antonyms: ['encode']
# Word: 'verb'
#   Synonyms: ['verb', 'verb']
#   Antonyms: []
# Word: 'files'
#   Synonyms: ['file', 'data_file', 'file', 'single_file', 'Indian_file', 'file', 'file_cabinet', 'filing_cabinet', 'file', 'file', 'register', 'file', 'file', 'charge', 'lodge', 'file', 'file', 'file_away']
#   Antonyms: []
# Word: 'shape'
#   Synonyms: ['shape', 'form', 'configuration', 'contour', 'conformation', 'shape', 'form', 'human_body', 'physical_body', 'material_body', 'soma', 'build', 'figure', 'physique', 'anatomy', 'shape', 'bod', 'chassis', 'frame', 'form', 'flesh', 'shape', 'embodiment', 'form', 'shape', 'cast', 'condition', 'shape', 'Supreme_Headquarters_Allied_Powers_Europe', 'SHAPE', 'form', 'shape', 'pattern', 'determine', 'shape', 'mold', 'influence', 'regulate', 'shape', 'form', 'work', 'mold', 'mould', 'forge', 'shape', 'form']
#   Antonyms: []
# Word: 'emotional'
#   Synonyms: ['emotional', 'emotional', 'emotional', 'aroused', 'emotional', 'excited', 'worked_up']
#   Antonyms: ['cerebral', 'unemotional']
# Word: 'document'
#   Synonyms: ['document', 'written_document', 'papers', 'document', 'document', 'text_file', 'document', 'document', 'document']
#   Antonyms: []
# Word: 'logo'
#   Synonyms: ['logo', 'logotype']
#   Antonyms: []
# Word: 'opinions'
#   Synonyms: ['opinion', 'sentiment', 'persuasion', 'view', 'thought', 'opinion', 'view', 'public_opinion', 'popular_opinion', 'opinion', 'vox_populi', 'opinion', 'legal_opinion', 'judgment', 'judgement', 'opinion', 'ruling', 'impression', 'feeling', 'belief', 'notion', 'opinion']
#   Antonyms: []
# Word: 'process'
#   Synonyms: ['procedure', 'process', 'process', 'cognitive_process', 'mental_process', 'operation', 'cognitive_operation', 'summons', 'process', 'process', 'unconscious_process', 'process', 'outgrowth', 'appendage', 'process', 'physical_process', 'process', 'treat', 'process', 'process', 'action', 'sue', 'litigate', 'process', 'march', 'process', 'work', 'work_on', 'process', 'serve', 'process', 'swear_out']
#   Antonyms: []
# Word: 'entity'
#   Synonyms: ['entity']
#   Antonyms: []
# Word: 'improved'
#   Synonyms: ['better', 'improve', 'amend', 'ameliorate', 'meliorate', 'better', 'improve', 'ameliorate', 'meliorate', 'improved', 'improved', 'improved']
#   Antonyms: ['worsen', 'worsen', 'unimproved']
# Word: 'care'
#   Synonyms: ['care', 'attention', 'aid', 'tending', 'caution', 'precaution', 'care', 'forethought', 'concern', 'care', 'fear', 'care', 'care', 'charge', 'tutelage', 'guardianship', 'care', 'maintenance', 'upkeep', 'care', 'care', 'give_care', 'wish', 'care', 'like', 'manage', 'deal', 'care', 'handle', 'worry', 'care']
#   Antonyms: []
# Word: 'dates'
#   Synonyms: ['date', 'day_of_the_month', 'date', 'escort', 'date', 'appointment', 'engagement', 'date', 'particular_date', 'date', 'date', 'date', 'date', 'date', 'date', 'date_stamp', 'date', 'go_steady', 'go_out', 'date', 'see', 'date']
#   Antonyms: []
# Word: 'like'
#   Synonyms: ['like', 'the_like', 'the_likes_of', 'like', 'ilk', 'wish', 'care', 'like', 'like', 'like', 'like', 'like', 'like', 'similar', 'like', 'same', 'alike', 'similar', 'like', 'comparable', 'corresponding', 'like']
#   Antonyms: ['dislike', 'unlike', 'unlike', 'unalike']
# Word: 'identifies'
#   Synonyms: ['identify', 'place', 'name', 'identify', 'identify', 'identify', 'identify', 'discover', 'key', 'key_out', 'distinguish', 'describe', 'name', 'identify']
#   Antonyms: []
# Word: 'together'
#   Synonyms: ['together', 'together', 'together', 'together', 'together', 'together', 'unitedly', 'in_concert', 'together']
#   Antonyms: []
# Word: 'departments'
#   Synonyms: ['department', 'section', 'department', 'department']
#   Antonyms: []
# Word: 'terms'
#   Synonyms: ['footing', 'terms', 'price', 'terms', 'damage', 'term', 'term', 'condition', 'term', 'term', 'term', 'term', 'full_term', 'terminus', 'terminal_figure', 'term', 'term']
#   Antonyms: []
# Word: 'human'
#   Synonyms: ['homo', 'man', 'human_being', 'human', 'human', 'human', 'human']
#   Antonyms: ['nonhuman']
# Word: 'libraries'
#   Synonyms: ['library', 'library', 'library', 'depository_library', 'library', 'program_library', 'subroutine_library', 'library']
#   Antonyms: []
# Word: 'essential'
#   Synonyms: ['necessity', 'essential', 'requirement', 'requisite', 'necessary', 'essential', 'indispensable', 'essential', 'all-important', 'all_important', 'crucial', 'essential', 'of_the_essence', 'essential', 'substantive', 'essential']
#   Antonyms: ['inessential', 'inessential', 'adjective']
# Word: 'description'
#   Synonyms: ['description', 'verbal_description', 'description', 'description']
#   Antonyms: []
# Word: 'content'
#   Synonyms: ['content', 'message', 'content', 'subject_matter', 'substance', 'content', 'capacity', 'content', 'content', 'cognitive_content', 'mental_object', 'contentedness', 'content', 'subject', 'content', 'depicted_object', 'content', 'content', 'contented', 'content']
#   Antonyms: ['discontent', 'discontented']
# Word: 'inspecting'
#   Synonyms: ['inspect', 'visit', 'inspect', 'audit', 'scrutinize', 'scrutinise', 'inspect']
#   Antonyms: []
# Word: 'studies'
#   Synonyms: ['survey', 'study', 'study', 'work', 'report', 'study', 'written_report', 'study', 'study', 'discipline', 'subject', 'subject_area', 'subject_field', 'field', 'field_of_study', 'study', 'bailiwick', 'sketch', 'study', 'cogitation', 'study', 'study', 'study', 'analyze', 'analyse', 'study', 'examine', 'canvass', 'canvas', 'study', 'study', 'consider', 'learn', 'study', 'read', 'take', 'study', 'hit_the_books', 'study', 'meditate', 'contemplate']
#   Antonyms: []
# Word: 'emerged'
#   Synonyms: ['emerge', 'issue', 'emerge', 'come_out', 'come_forth', 'go_forth', 'egress', 'emerge', 'emerge', 'come_forth', 'emerge']
#   Antonyms: []
# Word: 'with'
#   Synonyms: []
#   Antonyms: []
# Word: 'constitutes'
#   Synonyms: ['constitute', 'represent', 'make_up', 'comprise', 'be', 'appoint', 'name', 'nominate', 'constitute', 'form', 'constitute', 'make', 'establish', 'found', 'plant', 'constitute', 'institute']
#   Antonyms: []
# Word: 'matters'
#   Synonyms: ['matter', 'affair', 'thing', 'topic', 'subject', 'issue', 'matter', 'matter', 'matter', 'matter', 'matter', 'count', 'matter', 'weigh']
#   Antonyms: []
# Word: 'platforms'
#   Synonyms: ['platform', 'platform', 'political_platform', 'political_program', 'program', 'platform', 'platform', 'weapons_platform', 'chopine', 'platform']
#   Antonyms: []
# Word: 'extracting'
#   Synonyms: ['extract', 'pull_out', 'pull', 'pull_up', 'take_out', 'draw_out', 'extract', 'educe', 'evoke', 'elicit', 'extract', 'draw_out', 'distill', 'extract', 'distil', 'extract', 'press_out', 'express', 'extract', 'excerpt', 'extract', 'take_out', 'extract']
#   Antonyms: []
# Word: 'processing'
#   Synonyms: ['processing', 'process', 'treat', 'process', 'process', 'action', 'sue', 'litigate', 'process', 'march', 'process', 'work', 'work_on', 'process', 'serve', 'process', 'swear_out']
#   Antonyms: []
# Word: 'apache'
#   Synonyms: ['Apache', 'apache', 'Apache']
#   Antonyms: []
# Word: 'businesses'
#   Synonyms: ['business', 'concern', 'business_concern', 'business_organization', 'business_organisation', 'commercial_enterprise', 'business_enterprise', 'business', 'occupation', 'business', 'job', 'line_of_work', 'line', 'business', 'business', 'business', 'business', 'business_sector', 'clientele', 'patronage', 'business', 'business', 'stage_business', 'byplay']
#   Antonyms: []

# %% [markdown]
# PMI

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
from collections import Counter

# Function to scrape text from a webpage
def scrape_text_from_url(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract all the text content from the page
    paragraphs = soup.find_all('p')
    text = ' '.join([para.get_text() for para in paragraphs])

    return text

# Example URL to scrape
url = 'https://en.wikipedia.org/wiki/Natural_language_processing'
scraped_text = scrape_text_from_url(url)

# Preprocess scraped text
words = scraped_text.split()  # Splitting text into words
word_freq = Counter(words)    # Count word frequencies
total_words = len(words)      # Total number of words in the corpus
print(f"Total words: {total_words}")

# Function to calculate PMI
def pmi(word1, word2):
    # Calculate joint frequency (how many sentences contain both words)
    sentences = scraped_text.split('.')
    joint_freq = sum(1 for sentence in sentences if word1 in sentence and word2 in sentence)

    # Calculate probabilities
    p_word1 = word_freq[word1] / total_words
    p_word2 = word_freq[word2] / total_words
    p_joint = joint_freq / len(sentences)

    # Calculate PMI
    return np.log2(p_joint / (p_word1 * p_word2)) if p_joint > 0 else None

# Example: Calculate PMI for 'language' and 'processing'
word1, word2 = 'language', 'processing'
result = pmi(word1, word2)
print(f"PMI({word1}, {word2}) = {result}")
# Out:
# Total words: 1086
# PMI(language, processing) = 10.656283951868597

# %%
import http.client
import re
import numpy as np
from collections import Counter

# Function to scrape text from a webpage
def scrape_text_from_url(url):
    # Parse the URL
    protocol, _, domain, path = url.split('/', 3)
    conn = http.client.HTTPSConnection(domain)  # Use HTTPConnection for http URLs
    conn.request("GET", "/" + path)
    response = conn.getresponse()

    # Read and decode the response
    html = response.read().decode('utf-8')

    # Use regex to extract text from <p> tags
    paragraphs = re.findall(r'<p>(.*?)</p>', html, re.DOTALL)
    text = ' '.join([re.sub(r'<.*?>', '', para) for para in paragraphs])  # Remove HTML tags

    return text

# Example URL to scrape
url = 'https://en.wikipedia.org/wiki/Natural_language_processing'
scraped_text = scrape_text_from_url(url)

# Preprocess scraped text
words = re.findall(r'\b\w+\b', scraped_text.lower())  # Extract words and convert to lowercase
word_freq = Counter(words)                            # Count word frequencies
total_words = len(words)                              # Total number of words in the corpus
print(f"Total words: {total_words}")

# Function to calculate PMI
def pmi(word1, word2):
    # Calculate joint frequency (how many sentences contain both words)
    sentences = re.split(r'[.!?]', scraped_text)  # Split text into sentences
    joint_freq = sum(1 for sentence in sentences if word1 in sentence and word2 in sentence)

    # Calculate probabilities
    p_word1 = word_freq[word1] / total_words
    p_word2 = word_freq[word2] / total_words
    p_joint = joint_freq / len(sentences)

    # Calculate PMI
    return np.log2(p_joint / (p_word1 * p_word2)) if p_joint > 0 else None

# List of word pairs to calculate PMI for
word_pairs = [('language', 'processing'), ('natural', 'language'), ('cat', 'dog'), ('model', 'training')]

# Calculate PMI for each word pair
for word1, word2 in word_pairs:
    result = pmi(word1, word2)
    if result is not None:
        print(f"PMI({word1}, {word2}) = {result}")
    else:
        print(f"PMI({word1}, {word2}) could not be calculated.")
# Out:
# Total words: 1221
# PMI(language, processing) = 10.052778832460003
# PMI(natural, language) = 9.775244856931094
# PMI(cat, dog) could not be calculated.
# PMI(model, training) could not be calculated.

# %% [markdown]
# VECTOR SEMANTICS

# %%
import spacy

# Load the small English model
nlp = spacy.load('en_core_web_sm')

# Small dataset (manually entered sentences)
small_sentences = [
    'the cat sat on the mat',
    'dogs are better than cats',
    'the dog sat on the rug'
]

# Process sentences and get vectors for each word
for sentence in small_sentences:
    doc = nlp(sentence)
    print(f"\nSentence: {sentence}")
    for token in doc:
        print(f"Word: {token.text}, Vector: {token.vector[:5]}")  # Truncated vector output
# Out:
# Sentence: the cat sat on the mat
# Word: the, Vector: [ 1.2190363  -0.47780147 -0.02257838  1.8145945  -1.2888143 ]
# Word: cat, Vector: [-0.49857017 -0.46915686 -0.7442478   0.39140272  0.29465148]
# Word: sat, Vector: [-0.04254475  0.9221249   0.60993016 -0.87227887 -0.29893935]
# Word: on, Vector: [ 0.31212795  0.42844406  0.36984378 -0.95197976  0.3493223 ]
# Word: the, Vector: [ 1.0240833  -0.03962332 -1.1507094   1.0001687   0.58538896]
# Word: mat, Vector: [ 0.7723417 -1.6352618  0.1364181 -1.206529  -0.4052785]
#
# Sentence: dogs are better than cats
# Word: dogs, Vector: [-0.41797087  0.99235207  0.5725043   0.77076995  0.71824205]
# Word: are, Vector: [ 0.09023796  0.62270015 -0.709143   -0.2652374  -0.28411064]
# Word: better, Vector: [ 0.9536653   0.04835802  0.2381073  -1.2686076  -1.4762766 ]
# Word: than, Vector: [ 0.36181647 -0.3444981  -0.41358137 -0.7631421  -0.24953336]
# Word: cats, Vector: [-1.1452069   0.29329747 -1.1624678   1.1739498   0.6667417 ]
#
# Sentence: the dog sat on the rug
# Word: the, Vector: [ 1.4026988  -0.41027075  0.21928567  1.8628728  -0.5718813 ]
# Word: dog, Vector: [-1.2325946  -0.61640644 -1.2499554   0.501817    0.6357027 ]
# Word: sat, Vector: [ 0.09363857  1.2517352   0.3160711  -0.8030669  -0.32842705]
# Word: on, Vector: [ 0.14091814  0.628064    0.49084404 -1.0351682   0.3995161 ]
# Word: the, Vector: [ 1.1595832   0.24231006 -0.2794866   1.0228527   0.26518825]
# Word: rug, Vector: [-0.5615624  -1.2655779   0.400512    0.04053411 -0.23777768]

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-md==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.66.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (13.9.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import requests
from bs4 import BeautifulSoup
import spacy

# Load the medium English model
nlp = spacy.load('en_core_web_md')

# Web scraping to collect text from a website (e.g., Wikipedia)
def scrape_webpage(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extracting paragraphs from the webpage
    paragraphs = soup.find_all('p')
    text = " ".join([para.get_text() for para in paragraphs])
    return text

# Scraping data from multiple Wikipedia pages (big dataset)
urls = [
    'https://en.wikipedia.org/wiki/Machine_learning',
    'https://en.wikipedia.org/wiki/Artificial_intelligence',
    'https://en.wikipedia.org/wiki/Natural_language_processing'
]

# Collecting text from the pages
large_text_data = [scrape_webpage(url) for url in urls]

# Process scraped text using spaCy
for text in large_text_data:
    doc = nlp(text[:500])  # Processing first 500 characters (for example)
    print(f"\nSample text: {text[:100]}...")  # Print the first 100 characters
    for token in doc:
        print(f"Word: {token.text}, Vector: {token.vector[:5]}")  # Truncated vector
# Out:
# Sample text: Machine learning (ML) is a field of study in artificial intelligence concerned with the development ...
# Word: Machine, Vector: [-2.3291  -0.47575  4.2706   6.4718   3.7222 ]
# Word: learning, Vector: [ 0.52415 -0.11843  0.99918 -0.92592  0.58506]
# Word: (, Vector: [ -7.8392   -10.463     11.759      1.8131     0.046077]
# Word: ML, Vector: [ 0.61869 12.587   16.028    4.7017  -3.5819 ]
# Word: ), Vector: [-7.9729 -8.4028 11.931   1.4241 -6.2634]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: a, Vector: [-9.3629  9.2761 -7.2708  4.3879 10.316 ]
# Word: field, Vector: [-0.96889  5.7225  -0.24339 -1.2014   5.5839 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: study, Vector: [-0.64776 -1.3091   2.0104  -1.2484  -2.4662 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: artificial, Vector: [-1.5015  -0.71667 -0.62862  0.15832  2.285  ]
# Word: intelligence, Vector: [-0.41817  0.3404  -1.1554   1.9992   3.1846 ]
# Word: concerned, Vector: [-1.1494  1.7221 -2.2362 -2.9736  3.8596]
# Word: with, Vector: [-7.3029  -1.8444  -0.76674  2.971    8.2274 ]
# Word: the, Vector: [-5.1043  2.3496  3.2472  2.8424 11.459 ]
# Word: development, Vector: [-1.3517  -0.99684  2.9856  -0.58854  1.51   ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: study, Vector: [-0.64776 -1.3091   2.0104  -1.2484  -2.4662 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: statistical, Vector: [-1.8019  -0.62901  2.6814   3.1351   4.4443 ]
# Word: algorithms, Vector: [-0.78099  3.0394   2.6835   1.1991   1.8776 ]
# Word: that, Vector: [-1.1026  2.9549 -2.8606 -1.3667  1.4727]
# Word: can, Vector: [ 11.126    7.0777 -10.742   -4.4756  -3.1822]
# Word: learn, Vector: [ 2.7364   0.92233  1.0508  -5.2812  -3.5476 ]
# Word: from, Vector: [ 0.45435 -6.0338  -1.8677  -1.8194   8.5512 ]
# Word: data, Vector: [ 8.433   -0.62196  4.5699   4.2771   7.5471 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: generalize, Vector: [-3.7075   0.57065 -0.88245  1.5028   4.9025 ]
# Word: to, Vector: [ -1.6487   17.345   -10.544    -5.9622   -0.62663]
# Word: unseen, Vector: [ 2.1766    2.3892   -0.4601   -0.044466 -0.79943 ]
# Word: data, Vector: [ 8.433   -0.62196  4.5699   4.2771   7.5471 ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: thus, Vector: [-5.8837   0.19365 -3.6388  -1.3732   9.9756 ]
# Word: perform, Vector: [ 1.9534   2.8122  -1.272    0.43364  3.3374 ]
# Word: tasks, Vector: [ 1.4433  3.6491 -3.8759 -1.0531  6.2124]
# Word: without, Vector: [-3.9888   3.3829  -5.1079  -0.71275  4.9992 ]
# Word: explicit, Vector: [-3.0105    1.253     0.11372  -0.039351  3.3678  ]
# Word: instructions.[1, Vector: [0. 0. 0. 0. 0.]
# Word: ], Vector: [10.212  -6.6998  9.8893 -4.121  -1.8141]
# Word: Advances, Vector: [-1.0361   -1.5874    1.9606    1.6474   -0.054317]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: the, Vector: [-5.1043  2.3496  3.2472  2.8424 11.459 ]
# Word: field, Vector: [-0.96889  5.7225  -0.24339 -1.2014   5.5839 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: deep, Vector: [ 8.1642    3.3069   -4.9961    2.4166    0.049755]
# Word: learning, Vector: [ 0.52415 -0.11843  0.99918 -0.92592  0.58506]
# Word: have, Vector: [-2.2659  4.1936 -6.7259  1.0432 -2.3303]
# Word: allowed, Vector: [-0.63593  4.5676  -1.3617   2.0095   4.8076 ]
# Word: neural, Vector: [-1.6284    2.5901    0.66503  -0.063545  5.5166  ]
# Word: networks, Vector: [-1.8543   2.3119  -3.0068   0.31549  6.1404 ]
# Word: to, Vector: [ -1.6487   17.345   -10.544    -5.9622   -0.62663]
# Word: surpass, Vector: [-2.0609  -1.299   -1.1903   0.18515  3.395  ]
# Word: many, Vector: [-1.2656  -1.2687   0.55671  2.8463  -0.41218]
# Word: previous, Vector: [-2.1917  -1.4708   0.53707  0.17937  7.2821 ]
# Word: approaches, Vector: [ 0.15147  3.3666  -1.3625   0.30752  3.9117 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: performance.[2, Vector: [0. 0. 0. 0. 0.]
# Word: ], Vector: [10.212  -6.6998  9.8893 -4.121  -1.8141]
# Word:
#  , Vector: [0. 0. 0. 0. 0.]
# Word: ML, Vector: [ 0.61869 12.587   16.028    4.7017  -3.5819 ]
# Word: finds, Vector: [ 6.513    -0.035139  1.7127   -2.623     4.3024  ]
# Word: application, Vector: [-0.91324 -3.7551   3.1074   2.1344   2.2982 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: many, Vector: [-1.2656  -1.2687   0.55671  2.8463  -0.41218]
# Word: fields, Vector: [-0.43156  2.9642  -2.2553  -2.3156   5.8083 ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: including, Vector: [-2.9074  -5.505    0.36127  0.55051  7.1073 ]
# Word: natural, Vector: [-3.01   -2.1778 -2.2215 -1.9799  1.6367]
# Word: language, Vector: [-2.0524  -0.17297  5.4881  -2.2487   3.8744 ]
# Word: processing, Vector: [-0.98158 -2.6326  -0.02352  3.2856   3.63   ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: computer, Vector: [ 0.67285 -0.86102  1.6945  -0.60859  0.13298]
# Word: vision, Vector: [ 0.64275  3.578   -1.9499  -2.1879   1.7625 ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: speech, Vector: [-1.801   -2.1598  -0.33735 -0.33215  4.8358 ]
# Word: recognition, Vector: [-2.6285 -1.5406  1.2719  1.6314  6.7573]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: email, Vector: [ 5.8084 -5.1999  6.548   1.0931  5.232 ]
# Word: filterin, Vector: [0. 0. 0. 0. 0.]
#
# Sample text:
#  Artificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, partic...
# Word:
#  , Vector: [0. 0. 0. 0. 0.]
# Word: Artificial, Vector: [-1.6952 -1.5868  2.6415  1.4848  2.3921]
# Word: intelligence, Vector: [-0.41817  0.3404  -1.1554   1.9992   3.1846 ]
# Word: (, Vector: [ -7.8392   -10.463     11.759      1.8131     0.046077]
# Word: AI, Vector: [ 0.61869 12.587   16.028    4.7017  -3.5819 ]
# Word: ), Vector: [-7.9729 -8.4028 11.931   1.4241 -6.2634]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: its, Vector: [-2.1506  4.845   1.3031  2.005  17.474 ]
# Word: broadest, Vector: [ 0.31247  2.829   -2.4297   1.3853   2.0962 ]
# Word: sense, Vector: [-0.18443 -0.35219 -4.3622   1.1857   1.6129 ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: intelligence, Vector: [-0.41817  0.3404  -1.1554   1.9992   3.1846 ]
# Word: exhibited, Vector: [-3.1937 -1.4373 -1.399  -1.0839  4.9953]
# Word: by, Vector: [-13.597  -10.16    -7.4742  -1.3009   1.3852]
# Word: machines, Vector: [-2.084   -0.34871  0.18769  5.5899   2.6519 ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: particularly, Vector: [-1.4496   -0.59818  -0.054822 -0.087338  3.9537  ]
# Word: computer, Vector: [ 0.67285 -0.86102  1.6945  -0.60859  0.13298]
# Word: systems, Vector: [-1.4656 -1.6261 -1.2691  3.3806  5.9382]
# Word: ., Vector: [-0.076454 -4.6896   -4.0431   -3.4333   11.758   ]
# Word: It, Vector: [ 8.6598  4.9852 -4.7702 -4.0454  2.6053]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: a, Vector: [-9.3629  9.2761 -7.2708  4.3879 10.316 ]
# Word: field, Vector: [-0.96889  5.7225  -0.24339 -1.2014   5.5839 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: research, Vector: [ 0.80931 -0.22587  1.7245  -2.2466   2.2856 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: computer, Vector: [ 0.67285 -0.86102  1.6945  -0.60859  0.13298]
# Word: science, Vector: [ 0.75194 -0.79828  1.2442  -4.2597   0.71815]
# Word: that, Vector: [-1.1026  2.9549 -2.8606 -1.3667  1.4727]
# Word: develops, Vector: [-0.37274 -0.61739  2.8145  -1.3622   1.0591 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: studies, Vector: [-0.020262  2.0661    1.1553   -0.081346  3.102   ]
# Word: methods, Vector: [-0.56059  1.2214   1.4484   1.2296   4.1601 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: software, Vector: [ 0.56288 -0.96299  3.242    0.98995  2.6731 ]
# Word: that, Vector: [-1.1026  2.9549 -2.8606 -1.3667  1.4727]
# Word: enable, Vector: [ 0.70036  2.1057  -1.6443   2.9426   4.8116 ]
# Word: machines, Vector: [-2.084   -0.34871  0.18769  5.5899   2.6519 ]
# Word: to, Vector: [ -1.6487   17.345   -10.544    -5.9622   -0.62663]
# Word: perceive, Vector: [-0.79341  0.94592 -1.8557   0.10406  0.44836]
# Word: their, Vector: [-3.8402  3.8243 -5.4301  0.9187 11.119 ]
# Word: environment, Vector: [-0.36877 -0.68943 -2.4761  -1.7734   1.1436 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: use, Vector: [-4.9378   -0.037231 -0.17189  -0.22314   3.3619  ]
# Word: learning, Vector: [ 0.52415 -0.11843  0.99918 -0.92592  0.58506]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: intelligence, Vector: [-0.41817  0.3404  -1.1554   1.9992   3.1846 ]
# Word: to, Vector: [ -1.6487   17.345   -10.544    -5.9622   -0.62663]
# Word: take, Vector: [ 4.5063 -0.9916 -6.8825 -0.6487  1.0315]
# Word: actions, Vector: [-1.5621  -0.90528 -4.1542   2.6256   5.4819 ]
# Word: that, Vector: [-1.1026  2.9549 -2.8606 -1.3667  1.4727]
# Word: maximize, Vector: [-3.0539  1.8506 -3.2907  2.2279  2.8287]
# Word: their, Vector: [-3.8402  3.8243 -5.4301  0.9187 11.119 ]
# Word: chances, Vector: [ 1.742    0.81231 -2.6251   2.1044   5.6507 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: achieving, Vector: [-3.1651  -0.23984 -1.8417   0.89321  2.6205 ]
# Word: defined, Vector: [-5.1564    0.81767   2.9399   -0.015095  4.1186  ]
# Word: goals.[1, Vector: [0. 0. 0. 0. 0.]
# Word: ], Vector: [10.212  -6.6998  9.8893 -4.121  -1.8141]
# Word: Such, Vector: [-0.87061 -0.72299 -1.6922  -1.857    1.0897 ]
# Word: machines, Vector: [-2.084   -0.34871  0.18769  5.5899   2.6519 ]
# Word: may, Vector: [ 6.292   9.4832 -6.3755 -2.8694 -1.372 ]
# Word: be, Vector: [-9.3526  3.6551 -3.2571  5.9911 -6.4846]
# Word: called, Vector: [-1.2363  -0.80152  3.0436  -0.11728  5.4239 ]
# Word: AIs, Vector: [-0.46613  1.3949  -1.9544   0.43963 -2.059  ]
# Word: ., Vector: [-0.076454 -4.6896   -4.0431   -3.4333   11.758   ]
# Word:
#  , Vector: [0. 0. 0. 0. 0.]
# Word: Some, Vector: [-4.1331 -1.5148 -1.2899 -0.3486 -2.2109]
# Word: high, Vector: [ 0.89045  1.0135  -2.5998   1.8176   6.079  ]
# Word: -, Vector: [-5.2115  3.509  -1.2917 11.139   9.1501]
# Word: profile, Vector: [ 3.6911  0.3702 -1.2076  3.9429  4.5813]
# Word: applications, Vector: [-0.45309 -2.4266   0.90603  3.3048   3.8376 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: AI, Vector: [ 0.61869 12.587   16.028    4.7017  -3.5819 ]
# Word: include, Vector: [-3.6529 -4.2636  1.1269  1.7457  6.1441]
# Word: advanced, Vector: [-1.7369   0.97517  1.572    1.6405   2.8722 ]
# Word: web, Vector: [ 7.0776  -2.8745   5.3176   1.7903   0.50122]
# Word: search, Vector: [2.8823  2.6597  1.4212  0.84056 0.16013]
# Word: engines, Vector: [ 0.16094   0.27401  -0.041338  2.6846    0.80356 ]
# Word: (, Vector: [ -7.8392   -10.463     11.759      1.8131     0.046077]
# Word: e.g., Vector: [-5.6572 -4.2656  4.1218  1.1141  4.897 ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: Google, Vector: [ 1.7625  -0.28477  3.955    4.0928  -1.0044 ]
# Word: S, Vector: [-10.752     9.1607   14.149    -0.57878   2.5698 ]
#
# Sample text: Natural language processing (NLP) is a subfield of computer science and especially artificial intell...
# Word: Natural, Vector: [-1.6209  -4.2642   2.4627  -0.87363  0.7351 ]
# Word: language, Vector: [-2.0524  -0.17297  5.4881  -2.2487   3.8744 ]
# Word: processing, Vector: [-0.98158 -2.6326  -0.02352  3.2856   3.63   ]
# Word: (, Vector: [ -7.8392   -10.463     11.759      1.8131     0.046077]
# Word: NLP, Vector: [-1.2606    0.065898  6.0885   -0.22722   0.83154 ]
# Word: ), Vector: [-7.9729 -8.4028 11.931   1.4241 -6.2634]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: a, Vector: [-9.3629  9.2761 -7.2708  4.3879 10.316 ]
# Word: subfield, Vector: [-0.96889  5.7225  -0.24339 -1.2014   5.5839 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: computer, Vector: [ 0.67285 -0.86102  1.6945  -0.60859  0.13298]
# Word: science, Vector: [ 0.75194 -0.79828  1.2442  -4.2597   0.71815]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: especially, Vector: [-1.5745  -0.8883  -1.1828   0.21981  3.5367 ]
# Word: artificial, Vector: [-1.5015  -0.71667 -0.62862  0.15832  2.285  ]
# Word: intelligence, Vector: [-0.41817  0.3404  -1.1554   1.9992   3.1846 ]
# Word: ., Vector: [-0.076454 -4.6896   -4.0431   -3.4333   11.758   ]
# Word: It, Vector: [ 8.6598  4.9852 -4.7702 -4.0454  2.6053]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: primarily, Vector: [-4.7126 -1.2413 -1.1336  3.5414  2.3472]
# Word: concerned, Vector: [-1.1494  1.7221 -2.2362 -2.9736  3.8596]
# Word: with, Vector: [-7.3029  -1.8444  -0.76674  2.971    8.2274 ]
# Word: providing, Vector: [-1.3737   -3.457    -2.7048    0.072593  4.1187  ]
# Word: computers, Vector: [-0.8035   0.20622  0.33595  0.91187  2.0401 ]
# Word: with, Vector: [-7.3029  -1.8444  -0.76674  2.971    8.2274 ]
# Word: the, Vector: [-5.1043  2.3496  3.2472  2.8424 11.459 ]
# Word: ability, Vector: [ 4.9379  3.2707 -5.962   1.7975  4.163 ]
# Word: to, Vector: [ -1.6487   17.345   -10.544    -5.9622   -0.62663]
# Word: process, Vector: [ 2.4545  -0.42762  0.7832   1.3341   4.0436 ]
# Word: data, Vector: [ 8.433   -0.62196  4.5699   4.2771   7.5471 ]
# Word: encoded, Vector: [-2.6096   0.39849  1.0399  -0.20521  4.424  ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: natural, Vector: [-3.01   -2.1778 -2.2215 -1.9799  1.6367]
# Word: language, Vector: [-2.0524  -0.17297  5.4881  -2.2487   3.8744 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: thus, Vector: [-5.8837   0.19365 -3.6388  -1.3732   9.9756 ]
# Word: closely, Vector: [-1.1818   1.315   -0.19226  0.43473  4.3389 ]
# Word: related, Vector: [ 0.46448 -3.891   -0.72823 -1.8751   6.0738 ]
# Word: to, Vector: [ -1.6487   17.345   -10.544    -5.9622   -0.62663]
# Word: information, Vector: [ 3.3318  -3.3207   3.116   -0.58441  4.2977 ]
# Word: retrieval, Vector: [-0.57762   0.070021  1.6223    0.16864   1.7385  ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: knowledge, Vector: [ 2.8741  -0.86283  1.002   -1.3132   0.50152]
# Word: representation, Vector: [-3.5461  -1.3504   0.87688  0.42878  4.4208 ]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: computational, Vector: [-1.6794  -0.52262  2.0809   0.42319  5.3319 ]
# Word: linguistics, Vector: [-4.3453    1.0271    4.1772   -0.020464  4.9911  ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: a, Vector: [-9.3629  9.2761 -7.2708  4.3879 10.316 ]
# Word: subfield, Vector: [-0.96889  5.7225  -0.24339 -1.2014   5.5839 ]
# Word: of, Vector: [-12.667    -6.568    -0.61537   4.9492   22.389  ]
# Word: linguistics, Vector: [-4.3453    1.0271    4.1772   -0.020464  4.9911  ]
# Word: ., Vector: [-0.076454 -4.6896   -4.0431   -3.4333   11.758   ]
# Word: Typically, Vector: [-2.0367  -0.84221 -1.9552   2.7995   2.0765 ]
# Word: data, Vector: [ 8.433   -0.62196  4.5699   4.2771   7.5471 ]
# Word: is, Vector: [ 1.475   6.0078  1.1205 -3.5874  3.7638]
# Word: collected, Vector: [-3.9725  -5.6725   0.76787 -0.16617  4.5845 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: text, Vector: [ 1.8153 -3.0974  7.8781  1.7159  1.3492]
# Word: corpora, Vector: [-1.4952   -1.4346   -4.6589    0.034537  4.1865  ]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: using, Vector: [-4.8955 -4.647  -1.1312  1.2651  0.8625]
# Word: either, Vector: [-3.9975  1.373  -2.3223  1.6721  2.0838]
# Word: rule, Vector: [-2.0826  3.8912  8.1787  3.2381  4.3166]
# Word: -, Vector: [-5.2115  3.509  -1.2917 11.139   9.1501]
# Word: based, Vector: [-4.1368  -4.6353   2.4195  -1.7256   0.77214]
# Word: ,, Vector: [-3.3899  -4.7034  -0.56101  1.2291   4.3298 ]
# Word: statistical, Vector: [-1.8019  -0.62901  2.6814   3.1351   4.4443 ]
# Word: or, Vector: [ -5.6923   -0.24647 -12.502    -0.84701   6.9974 ]
# Word: neural, Vector: [-1.6284    2.5901    0.66503  -0.063545  5.5166  ]
# Word: -, Vector: [-5.2115  3.509  -1.2917 11.139   9.1501]
# Word: based, Vector: [-4.1368  -4.6353   2.4195  -1.7256   0.77214]
# Word: approaches, Vector: [ 0.15147  3.3666  -1.3625   0.30752  3.9117 ]
# Word: in, Vector: [-3.7766   0.69426 -3.3805   2.705    8.6019 ]
# Word: machine, Vector: [-1.7952   0.88564  1.2995   5.3467   2.3356 ]
# Word: learning, Vector: [ 0.52415 -0.11843  0.99918 -0.92592  0.58506]
# Word: and, Vector: [-3.3477 -6.0854 -3.6366  0.5348  8.4195]
# Word: deep, Vector: [ 8.1642    3.3069   -4.9961    2.4166    0.049755]
# Word: learn, Vector: [ 2.7364   0.92233  1.0508  -5.2812  -3.5476 ]
